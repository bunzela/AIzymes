# %%
# %run src/plm_trainer.py

from src.tools import reset_cuda
reset_cuda()

esm2_model_name      = "facebook/esm2_t33_650M_UR50D"
esm2_model_name      = "facebook/esm2_t30_150M_UR50D"
esm2_model_name      = "facebook/esm2_t12_35M_UR50D"
esm2_model_name      = "facebook/esm2_t6_8M_UR50D"

for p_loss in [0.0,0.1,0.2,0.3]:
    for esm2_model_name in ["facebook/esm2_t6_8M_UR50D","facebook/esm2_t12_35M_UR50D","facebook/esm2_t30_150M_UR50D","facebook/esm2_t33_650M_UR50D","facebook/esm2_t36_3B_UR50D","facebook/esm2_t48_15B_UR50D"]:
    
        output_folder        = '../../AIzymes_resi99'
        df_path              = './data/240705_all_scores_resi99.csv'
        cat_resi             = 99
        epochs               = 20        

        reset_cuda()
        
        dataset = PLM_trainer(
            output_folder   = output_folder,
            verbose         = False
            )

        PLM_trainer.load_dataset(    
            dataset,            
            df_path         = df_path,
            score           = 'interface_score',
            labels          = ['score_taken_from', 'design_method', 'cat_resn', 'cat_resi', 'parent_index', 'generation', 'mutations'],
            cat_resi        = cat_resi,
            select_unique   = True
            )

        PLM_trainer.train_PLM( 
            dataset,
            epochs          = epochs,
            esm2_model_name = esm2_model_name,
            p_loss          = p_loss 
            )
# Out:
# ### PLM trainer loaded. ###
# ### Data loaded from: ./data/240705_all_scores_resi99.csv ###
# ### Data normalized. ###
#   0%|          | 0/20 [00:10<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 35
#      21 dataset = PLM_trainer(
#      22     output_folder   = output_folder,
#      23     verbose         = False
#      24     )
#      26 PLM_trainer.load_dataset(
#      27     dataset,
#      28     df_path         = df_path,
#    (...)
#      32     select_unique   = True
#      33     )
# ---> 35 PLM_trainer.train_PLM(
#      36     dataset,
#      37     epochs          = epochs,
#      38     esm2_model_name = esm2_model_name,
#      39     p_loss          = p_loss
#      40     )
#
# File ~\Documents\GitHub\AIzymes\fitness_landscapes\src\plm_trainer.py:147, in PLM_trainer.train_PLM(self, epochs, esm2_model_name, p_loss)
# ...

# %%
# %run src/plm_trainer.py

for esm2_model_name in ["facebook/esm2_t6_8M_UR50D","facebook/esm2_t12_35M_UR50D","facebook/esm2_t30_150M_UR50D""facebook/esm2_t33_650M_UR50D"]:
    for p_loss in [0.0,0.1,0.2,0.3]:
    
        output_folder        = '../../AIzymes_resi99'
        df_path              = './data/240705_all_scores_resi99.csv'
        cat_resi             = 99
        epochs               = 20

        dataset = PLM_trainer(
            output_folder   = output_folder,
            verbose         = True
            )

        PLM_trainer.load_self_from_file(
            dataset,
            epochs          = epochs,
            esm2_model_name = esm2_model_name,
            cat_resi        = cat_resi,
            p_loss          = p_loss,
            df_path         = df_path
        )

        PLM_trainer.plot_learning(
            dataset
        )
# Out:
# ### PLM trainer loaded. ###
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t6_8M_UR50D_cat_99_epochs_20_ploss_0.0.pkl
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t6_8M_UR50D_cat_99_epochs_20_ploss_0.1.pkl
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t6_8M_UR50D_cat_99_epochs_20_ploss_0.2.pkl
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t6_8M_UR50D_cat_99_epochs_20_ploss_0.3.pkl
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t12_35M_UR50D_cat_99_epochs_20_ploss_0.0.pkl
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t12_35M_UR50D_cat_99_epochs_20_ploss_0.1.pkl
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t12_35M_UR50D_cat_99_epochs_20_ploss_0.2.pkl
# All variables loaded from ../../AIzymes_resi99/plm_self_model_esm2_t12_35M_UR50D_cat_99_epochs_20_ploss_0.3.pkl
# ...

# %%
""""
OUTLOOK

adjust for iterative learning?

"""
# Out:
# '"\nOUTLOOK\n\nadjust for iterative learning?\n\n'

# %%
 min for t6 8M
7    for t12
20 min for t30 150M
