# %% [markdown]
# ## Run function for the AIzyme algorithm, relies on the Function part

# %%
#### DESIGN RUN NAME #####################################################################################################
DESIGN_FOLDER     = 'LM_PMPNN_GRID_Functions_011'
FOLDER_MATCH      = 'MATCH' #Not needed for now -> This is just for match
FOLDER_PARENT     = f'../../design/Parent_1ohp' # -> Adjust, contains ONLY parent pdbs
##########################################################################################################################
#### Input parameters ####################################################################################################
MAX_JOBS          = 50
N_PARENT_JOBS     = 5
MAX_DESIGNS       = 200
KBT_BOLTZMANN     = 0.02
CST_WEIGHT        = 1.0
HIGHSCORE         = 0.93
NEG_BEST          = 0.79
ProteinMPNN_PROB  = 0.0
WT                = "1ohp"
LIGAND            = "5TS"
REPACK            = "36,45,51,67"
MATCH             = "14,18,26,30,55,65,80,82,99,101,112"
DESIGN            = "7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78"
DESIGN           += ",80,82,84,86,93,95,97,99,101,103,109,112,114,116,121"
ProteinMPNN_T     = "0.1"
SUBMIT_PREFIX     = "PMPNN" # Adjust, use a short prefix to allow 
BLUEPEBBLE        = False
GRID              = True
BACKGROUND_JOB    = False

if GRID:            ROSETTA_PATH = "/home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/"      #GRID
if BLUEPEBBLE:      
                    ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
                    BLUEPEBBLE_ACCOUNT = "ptch000361"
                    #BLUEPEBBLE_ACCOUNT = "ptch000721"
if BACKGROUND_JOB:  ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
    
NORM              = {'interface_score': [10, 30], 'total_score': [340, 410], 'catalytic_score': [-40, 0]}
##########################################################################################################################
AIZYME_TOOLS      = "../src/AIzymes_010.ipynb"
# %run "$AIZYME_TOOLS"
plot_scores()
# Out:
# AIzyme Functions loaded!
# catalytic_score [-40, 0] total_score [340, 410]
# NORMALIZATION ERROR! total_score has a value >1!
# interface_score [10, 30] HIGHSCORE: 0.94 Designs: 192 Parents: 1

# %%
# %run "$AIZYME_TOOLS"
controller(RESET=False, EXPLORE=False, UNBLOCK_ALL=False, PRINT_VAR=True, PLOT_DATA=False)
# Out:
# AIzyme Functions loaded!
# DESIGN_FOLDER    : LM_PMPNN_GRID_Functions_010
# FOLDER_MATCH     : MATCH
# MAX_JOBS         : 50
# N_PARENT_JOBS    : 10
# MAX_DESIGNS      : 1000
# KBT_BOLTZMANN    : 0.02
# CST_WEIGHT       : 1.0
# ProteinMPNN_PROB : 0.3
# WT               : 1ohp
# LIGAND           : 5TS
# ROSETTA_PATH     : /home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/
# REPACK           : 36,45,51,67
# DESIGN           : 7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78,80,82,84,86,93,95,97,99,101,103,109,112,114,116,121
# MATCH            : 14,18,26,30,55,65,80,82,99,101,112
# FOLDER_PARENT    : ../../design/Parent_1ohp
# ProteinMPNN_T    : 0.1
# SUBMIT_PREFIX    : PMPNN
# BLUEPEBBLE       : False
# GRID             : True
# BACKGROUND_JOB   : False
# EXPLORE          : False
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 192.
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 194.
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 195.
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 196.
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 197.
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 198.
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 199.
# 2024-03-26 10:11:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 200.
# 2024-03-26 10:11:42 - INFO - Run RosettaDesign for index 201 based on index 186.
# 2024-03-26 10:11:43 - INFO - Run RosettaDesign for index 202 based on index 133.
# 2024-03-26 10:12:59 - INFO - Ran ProteinMPNN for index 162 and found a new sequence with index 203.
# 2024-03-26 10:12:59 - INFO - Run ProteinMPNN for index 203 based on index 162.
# 2024-03-26 10:13:00 - INFO - Run RosettaDesign for index 204 based on index 172.
# 2024-03-26 10:13:02 - INFO - Run RosettaDesign for index 205 based on index 191.
# 2024-03-26 10:13:03 - INFO - Run RosettaDesign for index 206 based on index 113.
# 2024-03-26 10:13:04 - INFO - Run RosettaDesign for index 207 based on index 184.
# 2024-03-26 10:13:05 - INFO - Run RosettaDesign for index 208 based on index 133.
# 2024-03-26 10:13:07 - INFO - Run RosettaDesign for index 209 based on index 133.
# 2024-03-26 10:14:32 - INFO - Ran ProteinMPNN for index 169 and found a new sequence with index 210.
# 2024-03-26 10:14:32 - INFO - Run ProteinMPNN for index 210 based on index 169.
# 2024-03-26 10:15:56 - INFO - Ran ProteinMPNN for index 97 and found a new sequence with index 211.
# 2024-03-26 10:15:56 - INFO - Run ProteinMPNN for index 211 based on index 97.
# 2024-03-26 10:15:58 - INFO - Run RosettaDesign for index 212 based on index 67.
# 2024-03-26 10:15:59 - INFO - Run RosettaDesign for index 213 based on index 98.
# 2024-03-26 10:16:00 - INFO - Run RosettaDesign for index 214 based on index 179.
# 2024-03-26 10:16:01 - INFO - Run RosettaDesign for index 215 based on index 191.
# 2024-03-26 10:16:03 - INFO - Run RosettaDesign for index 216 based on index 172.
# 2024-03-26 10:16:04 - INFO - Run RosettaDesign for index 217 based on index 181.
# 2024-03-26 10:16:05 - INFO - Run RosettaDesign for index 218 based on index 133.
# 2024-03-26 10:16:06 - INFO - Run RosettaDesign for index 219 based on index 172.
# 2024-03-26 10:16:08 - INFO - Run RosettaDesign for index 220 based on index 28.
# 2024-03-26 10:17:27 - INFO - Ran ProteinMPNN for index 91 and found a new sequence with index 221.
# 2024-03-26 10:17:27 - INFO - Run ProteinMPNN for index 221 based on index 91.
# 2024-03-26 10:17:29 - INFO - Run RosettaDesign for index 222 based on index 76.
# 2024-03-26 10:17:30 - INFO - Run RosettaDesign for index 223 based on index 181.
# 2024-03-26 10:17:31 - INFO - Run RosettaDesign for index 224 based on index 83.
# 2024-03-26 10:17:32 - INFO - Run RosettaDesign for index 225 based on index 16.
# 2024-03-26 10:18:49 - INFO - Ran ProteinMPNN for index 174 and found a new sequence with index 226.
# 2024-03-26 10:18:49 - INFO - Run ProteinMPNN for index 226 based on index 174.
# 2024-03-26 10:18:51 - INFO - Run RosettaDesign for index 227 based on index 123.
# 2024-03-26 10:20:12 - INFO - Ran ProteinMPNN for index 140 and found a new sequence with index 228.
# 2024-03-26 10:20:12 - INFO - Run ProteinMPNN for index 228 based on index 140.
# 2024-03-26 10:21:25 - INFO - Ran ProteinMPNN for index 40 and found a new sequence with index 229.
# 2024-03-26 10:21:26 - INFO - Run ProteinMPNN for index 229 based on index 40.
# 2024-03-26 10:21:27 - INFO - Run RosettaDesign for index 230 based on index 81.
# 2024-03-26 10:21:28 - INFO - Run RosettaDesign for index 231 based on index 113.
# 2024-03-26 10:21:29 - INFO - Run RosettaDesign for index 232 based on index 191.
# 2024-03-26 10:21:31 - INFO - Run RosettaDesign for index 233 based on index 191.
# 2024-03-26 10:22:52 - INFO - Ran ProteinMPNN for index 67 and found a new sequence with index 234.
# 2024-03-26 10:22:52 - INFO - Run ProteinMPNN for index 234 based on index 67.
# 2024-03-26 10:22:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 211.
# 2024-03-26 10:22:53 - INFO - Run RosettaDesign for index 235 based on index 191.
# 2024-03-26 10:22:54 - INFO - Run RosettaDesign for index 236 based on index 91.
# 2024-03-26 10:22:56 - INFO - Run RosettaDesign for index 237 based on index 182.
# 2024-03-26 10:22:57 - INFO - Run RosettaDesign for index 238 based on index 172.
# 2024-03-26 10:22:58 - INFO - Run RosettaDesign for index 239 based on index 164.
# 2024-03-26 10:22:59 - INFO - Run RosettaDesign for index 240 based on index 170.
# 2024-03-26 10:23:01 - INFO - Run RosettaDesign for index 241 based on index 35.
# 2024-03-26 10:23:02 - INFO - Run RosettaDesign for index 242 based on index 181.
# 2024-03-26 10:23:03 - INFO - Run RosettaDesign for index 243 based on index 179.
# 2024-03-26 10:23:05 - INFO - Run RosettaDesign for index 244 based on index 87.
# 2024-03-26 10:23:06 - INFO - Run RosettaDesign for index 245 based on index 181.
# 2024-03-26 10:24:20 - INFO - Ran ProteinMPNN for index 181 and found a new sequence with index 246.
# 2024-03-26 10:24:20 - INFO - Run ProteinMPNN for index 246 based on index 181.
# 2024-03-26 10:24:22 - INFO - Run RosettaDesign for index 247 based on index 186.
# 2024-03-26 10:24:23 - INFO - Run RosettaDesign for index 248 based on index 184.
# 2024-03-26 10:24:24 - INFO - Run RosettaDesign for index 249 based on index 191.
# 2024-03-26 10:24:26 - INFO - Run RosettaDesign for index 250 based on index 97.
# 2024-03-26 10:24:27 - INFO - Run RosettaDesign for index 251 based on index 192.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_24430/425621151.py in <module>
#       1 get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
# ----> 2 controller(RESET=False, EXPLORE=False, UNBLOCK_ALL=False, PRINT_VAR=True, PLOT_DATA=False)
#
# /tmp/ipykernel_24430/4224228984.py in controller(RESET, EXPLORE, UNBLOCK_ALL, PRINT_VAR, PLOT_DATA, BLUEPEBBLE, GRID)
#      21         if num_running_jobs >= MAX_JOBS:
#      22
# ---> 23             time.sleep(60)
#      24
#      25         else:
#
# KeyboardInterrupt:

# %%
# !qstat | grep PMPNN
#!qstat | grep MATCH | awk '{print $1}' | xargs -I {} qdel {}

# %%
# %run "$AIZYME_TOOLS"
all_scores_df = pd.read_csv(f"{DESIGN_FOLDER}/all_scores.csv")
display(all_scores_df)

# %%
# %run "$AIZYME_TOOLS"
get_best_structures()
# Out:
# AIzyme Functions loaded!
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_8535/2690132606.py in <module>
#       1 get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
# ----> 2 get_best_structures()
#
# /tmp/ipykernel_8535/2580291326.py in get_best_structures()
#     192
#     193     # Read the scores DataFrame
# --> 194     all_scores_df = pd.read_csv('/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv')
#     195
#     196     # Drop rows with NaN in 'total_score'
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: '/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv'

# %%
# !qstat

# %%
make_empty_all_scores_df()
# Out:
# Empty DataFrame
# Columns: [index, sequence, parent_index, interface_score, total_score, catalytic_score, interface_potential, total_potential, catalytic_potential, relax_interface_score, relax_total_score, relax_catalytic_score, design_interface_score, design_total_score, design_catalytic_score, generation, mutations, design_method, score_taken_from, blocked, cat_resi, cat_resn]
# Index: []
#
# [0 rows x 22 columns]

# %%
# !qdel 859581 859582 859583 859584 859586 859587 859588 859589 859590 859594 859595 859600 859604 859610 859611 859613 859614 859615 859619 859620 859629 859632 859633 859634 859635 859636 859637 859638 859639 859640 859641 859642 859643 859644 859645 859646 859647 859648 859649 859650 859651 859652 859653 859654 859655 859656 859657 859658 859659 859660 859661 859662 859663 859664 859665 859666 859667 859668 859669 859670 859671 859672 859673 859674 859675 859676
# Out:
# lmerlicek has registered the job 859581 for deletion
# lmerlicek has registered the job 859582 for deletion
# lmerlicek has registered the job 859583 for deletion
# lmerlicek has registered the job 859584 for deletion
# lmerlicek has registered the job 859586 for deletion
# lmerlicek has registered the job 859587 for deletion
# lmerlicek has registered the job 859588 for deletion
# job 859589 is already in deletion
# lmerlicek has registered the job 859590 for deletion
# job 859594 is already in deletion
# job 859595 is already in deletion
# lmerlicek has registered the job 859600 for deletion
# denied: job "859604" does not exist
# denied: job "859610" does not exist
# lmerlicek has registered the job 859611 for deletion
# lmerlicek has registered the job 859613 for deletion
# denied: job "859614" does not exist
# lmerlicek has registered the job 859615 for deletion
# lmerlicek has registered the job 859619 for deletion
# lmerlicek has registered the job 859620 for deletion
# denied: job "859629" does not exist
# lmerlicek has registered the job 859632 for deletion
# lmerlicek has registered the job 859633 for deletion
# lmerlicek has registered the job 859634 for deletion
# lmerlicek has registered the job 859635 for deletion
# lmerlicek has registered the job 859636 for deletion
# lmerlicek has registered the job 859637 for deletion
# lmerlicek has registered the job 859638 for deletion
# lmerlicek has registered the job 859639 for deletion
# lmerlicek has registered the job 859640 for deletion
# lmerlicek has registered the job 859641 for deletion
# lmerlicek has registered the job 859642 for deletion
# lmerlicek has registered the job 859643 for deletion
# lmerlicek has registered the job 859644 for deletion
# lmerlicek has registered the job 859645 for deletion
# lmerlicek has registered the job 859646 for deletion
# lmerlicek has registered the job 859647 for deletion
# lmerlicek has registered the job 859648 for deletion
# lmerlicek has registered the job 859649 for deletion
# lmerlicek has registered the job 859650 for deletion
# lmerlicek has registered the job 859651 for deletion
# lmerlicek has registered the job 859652 for deletion
# lmerlicek has registered the job 859653 for deletion
# lmerlicek has registered the job 859654 for deletion
# lmerlicek has registered the job 859655 for deletion
# lmerlicek has registered the job 859656 for deletion
# lmerlicek has registered the job 859657 for deletion
# lmerlicek has registered the job 859658 for deletion
# lmerlicek has registered the job 859659 for deletion
# lmerlicek has registered the job 859660 for deletion
# lmerlicek has registered the job 859661 for deletion
# lmerlicek has registered the job 859662 for deletion
# lmerlicek has registered the job 859663 for deletion
# lmerlicek has registered the job 859664 for deletion
# lmerlicek has registered the job 859665 for deletion
# lmerlicek has registered the job 859666 for deletion
# lmerlicek has registered the job 859667 for deletion
# lmerlicek has registered the job 859668 for deletion
# lmerlicek has registered the job 859669 for deletion
# lmerlicek has registered the job 859670 for deletion
# lmerlicek has registered the job 859671 for deletion
# lmerlicek has registered the job 859672 for deletion
# lmerlicek has registered the job 859673 for deletion
# lmerlicek has registered the job 859674 for deletion
# lmerlicek has registered the job 859675 for deletion
# lmerlicek has registered the job 859676 for deletion
