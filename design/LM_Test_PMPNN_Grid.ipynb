# %% [markdown]
# ## Run function for the AIzyme algorithm, relies on the Function part

# %%
#### DESIGN RUN NAME #####################################################################################################
DESIGN_FOLDER     = 'LM_PMPNN_GRID_Functions_011'
FOLDER_MATCH      = 'MATCH' #Not needed for now -> This is just for match
FOLDER_PARENT     = f'../../design/Parent_1ohp' # -> Adjust, contains ONLY parent pdbs
##########################################################################################################################
#### Input parameters ####################################################################################################
MAX_JOBS          = 70
N_PARENT_JOBS     = 10
MAX_DESIGNS       = 20000
KBT_BOLTZMANN     = 0.02
CST_WEIGHT        = 1.0
HIGHSCORE         = 0.93
NEG_BEST          = 0.79
ProteinMPNN_PROB  = 0.3
WT                = "1ohp"
LIGAND            = "5TS"
REPACK            = "36,45,51,67"
MATCH             = "14,18,26,30,55,65,80,82,99,101,112"
DESIGN            = "7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78"
DESIGN           += ",80,82,84,86,93,95,97,99,101,103,109,112,114,116,121"
ProteinMPNN_T     = "0.1"
SUBMIT_PREFIX     = "PMPNN" # Adjust, use a short prefix to allow 
BLUEPEBBLE        = False
GRID              = True
BACKGROUND_JOB    = False

if GRID:            ROSETTA_PATH = "/home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/"      #GRID
if BLUEPEBBLE:      
                    ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
                    BLUEPEBBLE_ACCOUNT = "ptch000361"
                    #BLUEPEBBLE_ACCOUNT = "ptch000721"
if BACKGROUND_JOB:  ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
    
NORM              = {'interface_score': [10, 35], 'total_score': [340, 500], 'catalytic_score': [-40, 0]}
##########################################################################################################################
AIZYME_TOOLS      = "../src/AIzymes_010.ipynb"
# %run "$AIZYME_TOOLS"
plot_scores()
# Out:
# AIzyme Functions loaded!
# catalytic_score [-40, 0] total_score [340, 500] interface_score [10, 35] HIGHSCORE: 0.85 Designs: 4644 Parents: 1

# %%
# %run "$AIZYME_TOOLS"
all_scores_df = pd.read_csv(ALL_SCORES_CSV)
run_LigandMPNN(1008, 9999, all_scores_df)
# Out:
# AIzyme Functions loaded!
# 2024-03-28 11:28:19 - ERROR - Command '['python', '/home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/../LigandMPNN/run.py', '--model_type', 'ligand_mpnn', '--seed', '37', '--pdb_path', '/home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/9999/LigandMPNN/1ohp_Rosetta_Relax_1008.pdb', '--out_folder', '/home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/9999/LigandMPNN', '--fixed_residues', 'A99']' failed with return code 1
# 2024-03-28 11:28:19 - ERROR -
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_28412/801362383.py in <module>
#       1 get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
#       2 all_scores_df = pd.read_csv(ALL_SCORES_CSV)
# ----> 3 run_LigandMPNN(1008, 9999, all_scores_df)
#
# /tmp/ipykernel_28412/3789573394.py in run_LigandMPNN(parent_index, new_index, all_scores_df)
#     616         #"--pack_side_chains", "1",
#     617         #"--number_of_packs_per_design", "4",
# --> 618         "--fixed_residues", fixed_residues
#     619     ])
#     620
#
# /tmp/ipykernel_28412/689787540.py in run_command(command)
#     247     """Wrapper to execute .py files in runntime with arguments"""
#     248     try:
# --> 249         result = subprocess.run(command, capture_output=True, text=True, check=True)
#     250         return result.stdout
#     251     except subprocess.CalledProcessError as e:
#
# ~/miniconda3/envs/py37/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     510         if check and retcode:
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#     514
#
# CalledProcessError: Command '['python', '/home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/../LigandMPNN/run.py', '--model_type', 'ligand_mpnn', '--seed', '37', '--pdb_path', '/home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/9999/LigandMPNN/1ohp_Rosetta_Relax_1008.pdb', '--out_folder', '/home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/9999/LigandMPNN', '--fixed_residues', 'A99']' returned non-zero exit status 1.

# %%
# %run "$AIZYME_TOOLS"
controller(RESET=False, EXPLORE=False, UNBLOCK_ALL=False, PRINT_VAR=True, PLOT_DATA=False)
# Out:
# AIzyme Functions loaded!
# DESIGN_FOLDER    : LM_PMPNN_GRID_Functions_011
# FOLDER_MATCH     : MATCH
# MAX_JOBS         : 70
# N_PARENT_JOBS    : 10
# MAX_DESIGNS      : 20000
# KBT_BOLTZMANN    : 0.02
# CST_WEIGHT       : 1.0
# ProteinMPNN_PROB : 0.3
# WT               : 1ohp
# LIGAND           : 5TS
# ROSETTA_PATH     : /home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/
# REPACK           : 36,45,51,67
# DESIGN           : 7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78,80,82,84,86,93,95,97,99,101,103,109,112,114,116,121
# MATCH            : 14,18,26,30,55,65,80,82,99,101,112
# FOLDER_PARENT    : ../../design/Parent_1ohp
# ProteinMPNN_T    : 0.1
# SUBMIT_PREFIX    : PMPNN
# BLUEPEBBLE       : False
# GRID             : True
# BACKGROUND_JOB   : False
# EXPLORE          : False
# 2024-03-26 16:21:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 108.
# 2024-03-26 16:21:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 114.
# 2024-03-26 16:21:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 116.
# 2024-03-26 16:21:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 131.
# 2024-03-26 16:21:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 160.
# 2024-03-26 16:21:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 162.
# 2024-03-26 16:21:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 170.
# 2024-03-26 16:21:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 171.
# 2024-03-26 16:21:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 183.
# 2024-03-26 16:21:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 184.
# 2024-03-26 16:21:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 185.
# 2024-03-26 16:21:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 186.
# 2024-03-26 16:21:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 187.
# 2024-03-26 16:21:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 189.
# 2024-03-26 16:21:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 191.
# 2024-03-26 16:21:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 193.
# 2024-03-26 16:21:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 194.
# 2024-03-26 16:21:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 195.
# 2024-03-26 16:21:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 196.
# 2024-03-26 16:21:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 199.
# 2024-03-26 16:21:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 200.
# 2024-03-26 16:21:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 202.
# 2024-03-26 16:21:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 203.
# 2024-03-26 16:21:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 204.
# 2024-03-26 16:21:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 205.
# 2024-03-26 16:21:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 206.
# 2024-03-26 16:21:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 208.
# 2024-03-26 16:21:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 209.
# 2024-03-26 16:21:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 210.
# 2024-03-26 16:21:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 211.
# 2024-03-26 16:21:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 212.
# 2024-03-26 16:21:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 213.
# 2024-03-26 16:21:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 214.
# 2024-03-26 16:21:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 216.
# 2024-03-26 16:21:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 217.
# 2024-03-26 16:21:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 218.
# 2024-03-26 16:21:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 219.
# 2024-03-26 16:21:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 220.
# 2024-03-26 16:21:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 221.
# 2024-03-26 16:21:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 222.
# 2024-03-26 16:21:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 223.
# 2024-03-26 16:21:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 224.
# 2024-03-26 16:21:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 225.
# 2024-03-26 16:21:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 226.
# 2024-03-26 16:21:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 227.
# 2024-03-26 16:21:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 228.
# 2024-03-26 16:21:33 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 229.
# 2024-03-26 16:21:33 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 230.
# 2024-03-26 16:21:33 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 231.
# 2024-03-26 16:21:33 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 232.
# 2024-03-26 16:21:33 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 233.
# 2024-03-26 16:21:33 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 234.
# 2024-03-26 16:23:03 - INFO - Ran ProteinMPNN for index 109 and found a new sequence with index 235.
# 2024-03-26 16:23:03 - INFO - Run ProteinMPNN for index 235 based on index 109.
# 2024-03-26 16:24:52 - INFO - Ran ProteinMPNN for index 230 and found a new sequence with index 236.
# 2024-03-26 16:24:52 - INFO - Run ProteinMPNN for index 236 based on index 230.
# 2024-03-26 16:24:53 - INFO - Index 226 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:24:53 - INFO - Run ESMfold & Rosetta_Relax for index 226.
# 2024-03-26 16:24:55 - INFO - Run RosettaDesign for index 237 based on index 199.
# 2024-03-26 16:24:56 - INFO - Run RosettaDesign for index 238 based on index 197.
# 2024-03-26 16:24:57 - INFO - Run RosettaDesign for index 239 based on index 144.
# 2024-03-26 16:26:35 - INFO - Ran ProteinMPNN for index 108 and found a new sequence with index 240.
# 2024-03-26 16:26:35 - INFO - Run ProteinMPNN for index 240 based on index 108.
# 2024-03-26 16:28:03 - INFO - Ran ProteinMPNN for index 231 and found a new sequence with index 241.
# 2024-03-26 16:28:03 - INFO - Run ProteinMPNN for index 241 based on index 231.
# 2024-03-26 16:28:05 - INFO - Run RosettaDesign for index 242 based on index 182.
# 2024-03-26 16:29:28 - INFO - Ran ProteinMPNN for index 177 and found a new sequence with index 243.
# 2024-03-26 16:29:28 - INFO - Run ProteinMPNN for index 243 based on index 177.
# 2024-03-26 16:29:30 - INFO - Index 187 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:29:30 - INFO - Run ESMfold & Rosetta_Relax for index 187.
# 2024-03-26 16:29:31 - INFO - Run RosettaDesign for index 244 based on index 171.
# 2024-03-26 16:31:02 - INFO - Ran ProteinMPNN for index 99 and found a new sequence with index 245.
# 2024-03-26 16:31:02 - INFO - Run ProteinMPNN for index 245 based on index 99.
# 2024-03-26 16:31:04 - INFO - Run RosettaDesign for index 246 based on index 177.
# 2024-03-26 16:31:05 - INFO - Run RosettaDesign for index 247 based on index 109.
# 2024-03-26 16:31:06 - INFO - Run RosettaDesign for index 248 based on index 207.
# 2024-03-26 16:32:53 - INFO - Ran ProteinMPNN for index 109 and found a new sequence with index 249.
# 2024-03-26 16:32:53 - INFO - Run ProteinMPNN for index 249 based on index 109.
# 2024-03-26 16:32:55 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 235.
# 2024-03-26 16:32:55 - INFO - Index 222 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:32:55 - INFO - Run ESMfold & Rosetta_Relax for index 222.
# 2024-03-26 16:34:57 - INFO - Ran ProteinMPNN for index 207 and found a new sequence with index 250.
# 2024-03-26 16:34:57 - INFO - Run ProteinMPNN for index 250 based on index 207.
# 2024-03-26 16:34:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 226.
# 2024-03-26 16:34:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 240.
# 2024-03-26 16:35:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 241.
# 2024-03-26 16:35:02 - INFO - Index 224 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:35:02 - INFO - Run ESMfold & Rosetta_Relax for index 224.
# 2024-03-26 16:36:22 - INFO - Ran ProteinMPNN for index 207 and found a new sequence with index 251.
# 2024-03-26 16:36:22 - INFO - Run ProteinMPNN for index 251 based on index 207.
# 2024-03-26 16:36:23 - INFO - Index 214 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:36:23 - INFO - Run ESMfold & Rosetta_Relax for index 214.
# 2024-03-26 16:37:46 - INFO - Ran ProteinMPNN for index 109 and found a new sequence with index 252.
# 2024-03-26 16:37:47 - INFO - Run ProteinMPNN for index 252 based on index 109.
# 2024-03-26 16:37:48 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 187.
# 2024-03-26 16:37:48 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 243.
# 2024-03-26 16:37:48 - INFO - Run RosettaDesign for index 253 based on index 210.
# 2024-03-26 16:37:50 - INFO - Run RosettaDesign for index 254 based on index 109.
# 2024-03-26 16:37:51 - INFO - Run RosettaDesign for index 255 based on index 198.
# 2024-03-26 16:37:52 - INFO - Run RosettaDesign for index 256 based on index 197.
# 2024-03-26 16:37:54 - INFO - Run RosettaDesign for index 257 based on index 210.
# 2024-03-26 16:37:55 - INFO - Index 229 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:37:55 - INFO - Run ESMfold & Rosetta_Relax for index 229.
# 2024-03-26 16:37:56 - INFO - Index 183 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:37:56 - INFO - Run ESMfold & Rosetta_Relax for index 183.
# 2024-03-26 16:37:57 - INFO - Index 189 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:37:57 - INFO - Run ESMfold & Rosetta_Relax for index 189.
# 2024-03-26 16:37:58 - INFO - Index 213 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:37:58 - INFO - Run ESMfold & Rosetta_Relax for index 213.
# 2024-03-26 16:38:00 - INFO - Index 220 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:00 - INFO - Run ESMfold & Rosetta_Relax for index 220.
# 2024-03-26 16:38:01 - INFO - Run RosettaDesign for index 258 based on index 94.
# 2024-03-26 16:38:02 - INFO - Index 165 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:02 - INFO - Run ESMfold & Rosetta_Relax for index 165.
# 2024-03-26 16:38:04 - INFO - Index 212 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:04 - INFO - Run ESMfold & Rosetta_Relax for index 212.
# 2024-03-26 16:38:05 - INFO - Run RosettaDesign for index 259 based on index 109.
# 2024-03-26 16:38:06 - INFO - Run RosettaDesign for index 260 based on index 199.
# 2024-03-26 16:38:08 - INFO - Run RosettaDesign for index 261 based on index 170.
# 2024-03-26 16:38:09 - INFO - Run RosettaDesign for index 262 based on index 215.
# 2024-03-26 16:38:10 - INFO - Index 206 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:10 - INFO - Run ESMfold & Rosetta_Relax for index 206.
# 2024-03-26 16:38:12 - INFO - Run RosettaDesign for index 263 based on index 207.
# 2024-03-26 16:38:13 - INFO - Run RosettaDesign for index 264 based on index 76.
# 2024-03-26 16:38:15 - INFO - Run RosettaDesign for index 265 based on index 140.
# 2024-03-26 16:38:16 - INFO - Index 217 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:16 - INFO - Run ESMfold & Rosetta_Relax for index 217.
# 2024-03-26 16:38:18 - INFO - Index 234 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:18 - INFO - Run ESMfold & Rosetta_Relax for index 234.
# 2024-03-26 16:38:20 - INFO - Run RosettaDesign for index 266 based on index 218.
# 2024-03-26 16:38:22 - INFO - Run RosettaDesign for index 267 based on index 99.
# 2024-03-26 16:38:23 - INFO - Index 139 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:23 - INFO - Run ESMfold & Rosetta_Relax for index 139.
# 2024-03-26 16:38:24 - INFO - Index 179 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:38:24 - INFO - Run ESMfold & Rosetta_Relax for index 179.
# 2024-03-26 16:38:25 - INFO - Run RosettaDesign for index 268 based on index 218.
# 2024-03-26 16:38:27 - INFO - Run RosettaDesign for index 269 based on index 170.
# 2024-03-26 16:39:42 - INFO - Ran ProteinMPNN for index 198 and found a new sequence with index 270.
# 2024-03-26 16:39:42 - INFO - Run ProteinMPNN for index 270 based on index 198.
# 2024-03-26 16:39:44 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 236.
# 2024-03-26 16:39:44 - INFO - Index 193 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:39:44 - INFO - Run ESMfold & Rosetta_Relax for index 193.
# 2024-03-26 16:39:46 - INFO - Run RosettaDesign for index 271 based on index 197.
# 2024-03-26 16:39:49 - INFO - Run RosettaDesign for index 272 based on index 171.
# 2024-03-26 16:41:12 - INFO - Ran ProteinMPNN for index 144 and found a new sequence with index 273.
# 2024-03-26 16:41:12 - INFO - Run ProteinMPNN for index 273 based on index 144.
# 2024-03-26 16:41:14 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 222.
# 2024-03-26 16:41:15 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 245.
# 2024-03-26 16:42:39 - INFO - Ran ProteinMPNN for index 210 and found a new sequence with index 274.
# 2024-03-26 16:42:39 - INFO - Run ProteinMPNN for index 274 based on index 210.
# 2024-03-26 16:42:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 249.
# 2024-03-26 16:42:41 - INFO - Run RosettaDesign for index 275 based on index 94.
# 2024-03-26 16:42:43 - INFO - Run RosettaDesign for index 276 based on index 170.
# 2024-03-26 16:42:46 - INFO - Run RosettaDesign for index 277 based on index 197.
# 2024-03-26 16:42:47 - INFO - Run RosettaDesign for index 278 based on index 222.
# 2024-03-26 16:42:48 - INFO - Run RosettaDesign for index 279 based on index 109.
# 2024-03-26 16:42:50 - INFO - Index 196 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:42:50 - INFO - Run ESMfold & Rosetta_Relax for index 196.
# 2024-03-26 16:42:52 - INFO - Run RosettaDesign for index 280 based on index 173.
# 2024-03-26 16:42:53 - INFO - Run RosettaDesign for index 281 based on index 245.
# 2024-03-26 16:44:15 - INFO - Ran ProteinMPNN for index 170 and found a new sequence with index 282.
# 2024-03-26 16:44:15 - INFO - Run ProteinMPNN for index 282 based on index 170.
# 2024-03-26 16:44:16 - INFO - Run RosettaDesign for index 283 based on index 245.
# 2024-03-26 16:45:43 - INFO - Ran ProteinMPNN for index 236 and found a new sequence with index 284.
# 2024-03-26 16:45:43 - INFO - Run ProteinMPNN for index 284 based on index 236.
# 2024-03-26 16:45:45 - INFO - Index 223 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:45:45 - INFO - Run ESMfold & Rosetta_Relax for index 223.
# 2024-03-26 16:45:47 - INFO - Run RosettaDesign for index 285 based on index 188.
# 2024-03-26 16:45:49 - INFO - Index 205 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:45:49 - INFO - Run ESMfold & Rosetta_Relax for index 205.
# 2024-03-26 16:45:51 - INFO - Run RosettaDesign for index 286 based on index 171.
# 2024-03-26 16:45:52 - INFO - Index 191 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:45:52 - INFO - Run ESMfold & Rosetta_Relax for index 191.
# 2024-03-26 16:47:23 - INFO - Ran ProteinMPNN for index 92 and found a new sequence with index 287.
# 2024-03-26 16:47:24 - INFO - Run ProteinMPNN for index 287 based on index 92.
# 2024-03-26 16:47:25 - INFO - Run RosettaDesign for index 288 based on index 245.
# 2024-03-26 16:47:27 - INFO - Run RosettaDesign for index 289 based on index 99.
# 2024-03-26 16:47:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 234.
# 2024-03-26 16:47:29 - INFO - Run RosettaDesign for index 290 based on index 222.
# 2024-03-26 16:47:31 - INFO - Run RosettaDesign for index 291 based on index 207.
# 2024-03-26 16:47:33 - INFO - Run RosettaDesign for index 292 based on index 128.
# 2024-03-26 16:47:34 - INFO - Run RosettaDesign for index 293 based on index 204.
# 2024-03-26 16:48:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 273.
# 2024-03-26 16:48:37 - INFO - Run RosettaDesign for index 294 based on index 249.
# 2024-03-26 16:49:39 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 239.
# 2024-03-26 16:49:40 - INFO - Run RosettaDesign for index 295 based on index 234.
# 2024-03-26 16:50:42 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 214.
# 2024-03-26 16:50:42 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 250.
# 2024-03-26 16:50:43 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 270.
# 2024-03-26 16:50:43 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 274.
# 2024-03-26 16:50:43 - INFO - Run RosettaDesign for index 296 based on index 245.
# 2024-03-26 16:50:44 - INFO - Run RosettaDesign for index 297 based on index 274.
# 2024-03-26 16:50:45 - INFO - Run RosettaDesign for index 298 based on index 170.
# 2024-03-26 16:50:47 - INFO - Index 195 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:50:47 - INFO - Run ESMfold & Rosetta_Relax for index 195.
# 2024-03-26 16:52:50 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 224.
# 2024-03-26 16:52:50 - INFO - Run RosettaDesign for index 299 based on index 210.
# 2024-03-26 16:53:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 238.
# 2024-03-26 16:53:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 252.
# 2024-03-26 16:53:53 - INFO - Index 228 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:53:53 - INFO - Run ESMfold & Rosetta_Relax for index 228.
# 2024-03-26 16:53:54 - INFO - Index 216 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 16:53:54 - INFO - Run ESMfold & Rosetta_Relax for index 216.
# 2024-03-26 16:53:56 - INFO - Run RosettaDesign for index 300 based on index 250.
# 2024-03-26 16:54:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 193.
# 2024-03-26 16:54:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 287.
# 2024-03-26 16:56:15 - INFO - Ran ProteinMPNN for index 82 and found a new sequence with index 301.
# 2024-03-26 16:56:15 - INFO - Run ProteinMPNN for index 301 based on index 82.
# 2024-03-26 16:56:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 242.
# 2024-03-26 16:56:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 246.
# 2024-03-26 16:56:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 248.
# 2024-03-26 16:56:17 - INFO - Run RosettaDesign for index 302 based on index 76.
# 2024-03-26 16:57:34 - INFO - Ran ProteinMPNN for index 231 and found a new sequence with index 303.
# 2024-03-26 16:57:34 - INFO - Run ProteinMPNN for index 303 based on index 231.
# 2024-03-26 16:57:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 206.
# 2024-03-26 16:58:54 - INFO - Ran ProteinMPNN for index 222 and found a new sequence with index 304.
# 2024-03-26 16:58:54 - INFO - Run ProteinMPNN for index 304 based on index 222.
# 2024-03-26 16:58:55 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 196.
# 2024-03-26 16:58:56 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 237.
# 2024-03-26 16:58:56 - INFO - Run RosettaDesign for index 305 based on index 214.
# 2024-03-26 17:00:15 - INFO - Ran ProteinMPNN for index 199 and found a new sequence with index 306.
# 2024-03-26 17:00:15 - INFO - Run ProteinMPNN for index 306 based on index 199.
# 2024-03-26 17:00:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 191.
# 2024-03-26 17:00:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 247.
# 2024-03-26 17:00:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 251.
# 2024-03-26 17:00:17 - INFO - Run RosettaDesign for index 307 based on index 270.
# 2024-03-26 17:00:18 - INFO - Run RosettaDesign for index 308 based on index 250.
# 2024-03-26 17:01:37 - INFO - Ran ProteinMPNN for index 252 and found a new sequence with index 309.
# 2024-03-26 17:01:37 - INFO - Run ProteinMPNN for index 309 based on index 252.
# 2024-03-26 17:01:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 228.
# 2024-03-26 17:01:39 - INFO - Run RosettaDesign for index 310 based on index 252.
# 2024-03-26 17:01:40 - INFO - Run RosettaDesign for index 311 based on index 274.
# 2024-03-26 17:01:41 - INFO - Run RosettaDesign for index 312 based on index 222.
# 2024-03-26 17:02:44 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 189.
# 2024-03-26 17:02:44 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 265.
# 2024-03-26 17:04:01 - INFO - Ran ProteinMPNN for index 171 and found a new sequence with index 313.
# 2024-03-26 17:04:01 - INFO - Run ProteinMPNN for index 313 based on index 171.
# 2024-03-26 17:04:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 217.
# 2024-03-26 17:04:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 220.
# 2024-03-26 17:04:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 244.
# 2024-03-26 17:04:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 266.
# 2024-03-26 17:04:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 282.
# 2024-03-26 17:04:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 301.
# 2024-03-26 17:04:03 - INFO - Run RosettaDesign for index 314 based on index 251.
# 2024-03-26 17:05:19 - INFO - Ran ProteinMPNN for index 207 and found a new sequence with index 315.
# 2024-03-26 17:05:19 - INFO - Run ProteinMPNN for index 315 based on index 207.
# 2024-03-26 17:05:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 272.
# 2024-03-26 17:05:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 284.
# 2024-03-26 17:06:35 - INFO - Ran ProteinMPNN for index 210 and found a new sequence with index 316.
# 2024-03-26 17:06:35 - INFO - Run ProteinMPNN for index 316 based on index 210.
# 2024-03-26 17:06:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 212.
# 2024-03-26 17:06:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 258.
# 2024-03-26 17:06:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 271.
# 2024-03-26 17:07:49 - INFO - Ran ProteinMPNN for index 171 and found a new sequence with index 317.
# 2024-03-26 17:07:49 - INFO - Run ProteinMPNN for index 317 based on index 171.
# 2024-03-26 17:07:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 213.
# 2024-03-26 17:07:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 229.
# 2024-03-26 17:07:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 262.
# 2024-03-26 17:07:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 264.
# 2024-03-26 17:07:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 275.
# 2024-03-26 17:07:52 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 276.
# 2024-03-26 17:07:52 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 279.
# 2024-03-26 17:07:52 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 306.
# 2024-03-26 17:09:07 - INFO - Ran ProteinMPNN for index 173 and found a new sequence with index 318.
# 2024-03-26 17:09:07 - INFO - Run ProteinMPNN for index 318 based on index 173.
# 2024-03-26 17:09:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 253.
# 2024-03-26 17:09:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 277.
# 2024-03-26 17:09:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 280.
# 2024-03-26 17:09:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 281.
# 2024-03-26 17:09:09 - INFO - Index 246 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:09:09 - INFO - Run ESMfold & Rosetta_Relax for index 246.
# 2024-03-26 17:09:10 - INFO - Run RosettaDesign for index 319 based on index 230.
# 2024-03-26 17:10:34 - INFO - Ran ProteinMPNN for index 235 and found a new sequence with index 320.
# 2024-03-26 17:10:34 - INFO - Run ProteinMPNN for index 320 based on index 235.
# 2024-03-26 17:10:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 195.
# 2024-03-26 17:10:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 255.
# 2024-03-26 17:10:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 257.
# 2024-03-26 17:10:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 259.
# 2024-03-26 17:10:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 261.
# 2024-03-26 17:10:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 263.
# 2024-03-26 17:10:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 285.
# 2024-03-26 17:10:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 286.
# 2024-03-26 17:10:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 309.
# 2024-03-26 17:10:38 - INFO - Index 221 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:10:38 - INFO - Run ESMfold & Rosetta_Relax for index 221.
# 2024-03-26 17:10:39 - INFO - Index 248 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:10:39 - INFO - Run ESMfold & Rosetta_Relax for index 248.
# 2024-03-26 17:10:40 - INFO - Index 255 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:10:40 - INFO - Run ESMfold & Rosetta_Relax for index 255.
# 2024-03-26 17:10:41 - INFO - Run RosettaDesign for index 321 based on index 206.
# 2024-03-26 17:10:43 - INFO - Run RosettaDesign for index 322 based on index 273.
# 2024-03-26 17:10:44 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 205.
# 2024-03-26 17:10:45 - INFO - Run RosettaDesign for index 323 based on index 234.
# 2024-03-26 17:10:47 - INFO - Index 261 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:10:47 - INFO - Run ESMfold & Rosetta_Relax for index 261.
# 2024-03-26 17:12:19 - INFO - Ran ProteinMPNN for index 228 and found a new sequence with index 324.
# 2024-03-26 17:12:19 - INFO - Run ProteinMPNN for index 324 based on index 228.
# 2024-03-26 17:12:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 223.
# 2024-03-26 17:12:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 254.
# 2024-03-26 17:12:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 260.
# 2024-03-26 17:12:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 267.
# 2024-03-26 17:12:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 268.
# 2024-03-26 17:12:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 291.
# 2024-03-26 17:12:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 292.
# 2024-03-26 17:12:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 313.
# 2024-03-26 17:14:00 - INFO - Ran ProteinMPNN for index 207 and found a new sequence with index 325.
# 2024-03-26 17:14:00 - INFO - Run ProteinMPNN for index 325 based on index 207.
# 2024-03-26 17:14:01 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 256.
# 2024-03-26 17:14:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 290.
# 2024-03-26 17:14:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 293.
# 2024-03-26 17:14:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 315.
# 2024-03-26 17:14:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 316.
# 2024-03-26 17:14:03 - INFO - Run RosettaDesign for index 326 based on index 229.
# 2024-03-26 17:14:04 - INFO - Index 247 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:14:04 - INFO - Run ESMfold & Rosetta_Relax for index 247.
# 2024-03-26 17:14:06 - INFO - Index 244 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:14:06 - INFO - Run ESMfold & Rosetta_Relax for index 244.
# 2024-03-26 17:14:08 - INFO - Run RosettaDesign for index 327 based on index 128.
# 2024-03-26 17:14:09 - INFO - Run RosettaDesign for index 328 based on index 198.
# 2024-03-26 17:15:41 - INFO - Ran ProteinMPNN for index 235 and found a new sequence with index 329.
# 2024-03-26 17:15:42 - INFO - Run ProteinMPNN for index 329 based on index 235.
# 2024-03-26 17:15:44 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 269.
# 2024-03-26 17:15:44 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 298.
# 2024-03-26 17:15:44 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 317.
# 2024-03-26 17:15:44 - INFO - Run RosettaDesign for index 330 based on index 206.
# 2024-03-26 17:17:14 - INFO - Ran ProteinMPNN for index 251 and found a new sequence with index 331.
# 2024-03-26 17:17:14 - INFO - Run ProteinMPNN for index 331 based on index 251.
# 2024-03-26 17:17:15 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 183.
# 2024-03-26 17:17:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 216.
# 2024-03-26 17:17:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 278.
# 2024-03-26 17:17:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 283.
# 2024-03-26 17:17:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 288.
# 2024-03-26 17:17:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 289.
# 2024-03-26 17:17:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 294.
# 2024-03-26 17:17:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 295.
# 2024-03-26 17:17:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 297.
# 2024-03-26 17:17:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 299.
# 2024-03-26 17:17:18 - INFO - Index 291 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:17:18 - INFO - Run ESMfold & Rosetta_Relax for index 291.
# 2024-03-26 17:18:45 - INFO - Ran ProteinMPNN for index 235 and found a new sequence with index 332.
# 2024-03-26 17:18:45 - INFO - Run ProteinMPNN for index 332 based on index 235.
# 2024-03-26 17:18:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 246.
# 2024-03-26 17:18:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 261.
# 2024-03-26 17:18:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 300.
# 2024-03-26 17:18:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 304.
# 2024-03-26 17:18:47 - INFO - Run RosettaDesign for index 333 based on index 116.
# 2024-03-26 17:18:49 - INFO - Run RosettaDesign for index 334 based on index 155.
# 2024-03-26 17:20:11 - INFO - Ran ProteinMPNN for index 128 and found a new sequence with index 335.
# 2024-03-26 17:20:11 - INFO - Run ProteinMPNN for index 335 based on index 128.
# 2024-03-26 17:20:12 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 296.
# 2024-03-26 17:20:13 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 303.
# 2024-03-26 17:20:13 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 320.
# 2024-03-26 17:20:14 - INFO - Index 299 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:20:14 - INFO - Run ESMfold & Rosetta_Relax for index 299.
# 2024-03-26 17:20:16 - INFO - Index 283 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:20:16 - INFO - Run ESMfold & Rosetta_Relax for index 283.
# 2024-03-26 17:20:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 302.
# 2024-03-26 17:21:34 - INFO - Ran ProteinMPNN for index 218 and found a new sequence with index 336.
# 2024-03-26 17:21:34 - INFO - Run ProteinMPNN for index 336 based on index 218.
# 2024-03-26 17:21:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 247.
# 2024-03-26 17:21:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 248.
# 2024-03-26 17:21:36 - INFO - Run RosettaDesign for index 337 based on index 247.
# 2024-03-26 17:22:56 - INFO - Ran ProteinMPNN for index 210 and found a new sequence with index 338.
# 2024-03-26 17:22:56 - INFO - Run ProteinMPNN for index 338 based on index 210.
# 2024-03-26 17:22:57 - INFO - Index 260 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:22:57 - INFO - Run ESMfold & Rosetta_Relax for index 260.
# 2024-03-26 17:22:59 - INFO - Index 286 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:22:59 - INFO - Run ESMfold & Rosetta_Relax for index 286.
# 2024-03-26 17:23:00 - INFO - Index 262 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:23:00 - INFO - Run ESMfold & Rosetta_Relax for index 262.
# 2024-03-26 17:23:01 - INFO - Run RosettaDesign for index 339 based on index 250.
# 2024-03-26 17:23:03 - INFO - Run RosettaDesign for index 340 based on index 171.
# 2024-03-26 17:23:04 - INFO - Run RosettaDesign for index 341 based on index 250.
# 2024-03-26 17:24:17 - INFO - Ran ProteinMPNN for index 207 and found a new sequence with index 342.
# 2024-03-26 17:24:17 - INFO - Run ProteinMPNN for index 342 based on index 207.
# 2024-03-26 17:24:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 305.
# 2024-03-26 17:24:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 329.
# 2024-03-26 17:24:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 331.
# 2024-03-26 17:24:21 - INFO - Run RosettaDesign for index 343 based on index 94.
# 2024-03-26 17:24:23 - INFO - Run RosettaDesign for index 344 based on index 331.
# 2024-03-26 17:24:25 - INFO - Run RosettaDesign for index 345 based on index 250.
# 2024-03-26 17:24:27 - INFO - Index 300 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:24:27 - INFO - Run ESMfold & Rosetta_Relax for index 300.
# 2024-03-26 17:24:29 - INFO - Run RosettaDesign for index 346 based on index 251.
# 2024-03-26 17:24:30 - INFO - Index 254 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:24:30 - INFO - Run ESMfold & Rosetta_Relax for index 254.
# 2024-03-26 17:24:32 - INFO - Index 238 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:24:32 - INFO - Run ESMfold & Rosetta_Relax for index 238.
# 2024-03-26 17:24:34 - INFO - Run RosettaDesign for index 347 based on index 315.
# 2024-03-26 17:25:52 - INFO - Ran ProteinMPNN for index 250 and found a new sequence with index 348.
# 2024-03-26 17:25:52 - INFO - Run ProteinMPNN for index 348 based on index 250.
# 2024-03-26 17:25:54 - INFO - Run RosettaDesign for index 349 based on index 191.
# 2024-03-26 17:25:55 - INFO - Run RosettaDesign for index 350 based on index 191.
# 2024-03-26 17:27:17 - INFO - Ran ProteinMPNN for index 218 and found a new sequence with index 351.
# 2024-03-26 17:27:17 - INFO - Run ProteinMPNN for index 351 based on index 218.
# 2024-03-26 17:27:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 291.
# 2024-03-26 17:27:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 308.
# 2024-03-26 17:27:19 - INFO - Run RosettaDesign for index 352 based on index 188.
# 2024-03-26 17:28:32 - INFO - Ran ProteinMPNN for index 316 and found a new sequence with index 353.
# 2024-03-26 17:28:33 - INFO - Run ProteinMPNN for index 353 based on index 316.
# 2024-03-26 17:28:34 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 283.
# 2024-03-26 17:28:34 - INFO - Run RosettaDesign for index 354 based on index 218.
# 2024-03-26 17:28:36 - INFO - Index 276 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:28:36 - INFO - Run ESMfold & Rosetta_Relax for index 276.
# 2024-03-26 17:28:37 - INFO - Index 264 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:28:37 - INFO - Run ESMfold & Rosetta_Relax for index 264.
# 2024-03-26 17:28:38 - INFO - Index 89 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:28:38 - INFO - Run ESMfold & Rosetta_Relax for index 89.
# 2024-03-26 17:28:40 - INFO - Run RosettaDesign for index 355 based on index 191.
# 2024-03-26 17:28:41 - INFO - Run RosettaDesign for index 356 based on index 249.
# 2024-03-26 17:28:42 - INFO - Index 297 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:28:42 - INFO - Run ESMfold & Rosetta_Relax for index 297.
# 2024-03-26 17:28:43 - INFO - Index 269 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:28:43 - INFO - Run ESMfold & Rosetta_Relax for index 269.
# 2024-03-26 17:28:45 - INFO - Run RosettaDesign for index 357 based on index 261.
# 2024-03-26 17:28:46 - INFO - Index 267 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:28:46 - INFO - Run ESMfold & Rosetta_Relax for index 267.
# 2024-03-26 17:30:01 - INFO - Ran ProteinMPNN for index 217 and found a new sequence with index 358.
# 2024-03-26 17:30:01 - INFO - Run ProteinMPNN for index 358 based on index 217.
# 2024-03-26 17:30:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 244.
# 2024-03-26 17:30:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 311.
# 2024-03-26 17:30:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 325.
# 2024-03-26 17:30:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 335.
# 2024-03-26 17:30:04 - INFO - Run RosettaDesign for index 359 based on index 183.
# 2024-03-26 17:30:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 310.
# 2024-03-26 17:31:19 - INFO - Ran ProteinMPNN for index 206 and found a new sequence with index 360.
# 2024-03-26 17:31:19 - INFO - Run ProteinMPNN for index 360 based on index 206.
# 2024-03-26 17:31:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 262.
# 2024-03-26 17:31:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 307.
# 2024-03-26 17:31:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 312.
# 2024-03-26 17:31:22 - INFO - Run RosettaDesign for index 361 based on index 183.
# 2024-03-26 17:31:23 - INFO - Index 272 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:31:24 - INFO - Run ESMfold & Rosetta_Relax for index 272.
# 2024-03-26 17:31:26 - INFO - Run RosettaDesign for index 362 based on index 303.
# 2024-03-26 17:31:27 - INFO - Run RosettaDesign for index 363 based on index 191.
# 2024-03-26 17:31:28 - INFO - Index 209 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:31:28 - INFO - Run ESMfold & Rosetta_Relax for index 209.
# 2024-03-26 17:31:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 314.
# 2024-03-26 17:31:30 - INFO - Index 310 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:31:30 - INFO - Run ESMfold & Rosetta_Relax for index 310.
# 2024-03-26 17:31:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 299.
# 2024-03-26 17:33:29 - INFO - Ran ProteinMPNN for index 306 and found a new sequence with index 364.
# 2024-03-26 17:33:29 - INFO - Run ProteinMPNN for index 364 based on index 306.
# 2024-03-26 17:33:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 238.
# 2024-03-26 17:33:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 332.
# 2024-03-26 17:33:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 342.
# 2024-03-26 17:33:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 348.
# 2024-03-26 17:33:32 - INFO - Run RosettaDesign for index 365 based on index 173.
# 2024-03-26 17:33:33 - INFO - Run RosettaDesign for index 366 based on index 348.
# 2024-03-26 17:33:34 - INFO - Run RosettaDesign for index 367 based on index 173.
# 2024-03-26 17:33:36 - INFO - Run RosettaDesign for index 368 based on index 249.
# 2024-03-26 17:35:05 - INFO - Ran ProteinMPNN for index 270 and found a new sequence with index 369.
# 2024-03-26 17:35:05 - INFO - Run ProteinMPNN for index 369 based on index 270.
# 2024-03-26 17:35:06 - INFO - Index 253 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:35:07 - INFO - Run ESMfold & Rosetta_Relax for index 253.
# 2024-03-26 17:35:08 - INFO - Run RosettaDesign for index 370 based on index 201.
# 2024-03-26 17:35:09 - INFO - Run RosettaDesign for index 371 based on index 86.
# 2024-03-26 17:35:11 - INFO - Run RosettaDesign for index 372 based on index 247.
# 2024-03-26 17:35:12 - INFO - Run RosettaDesign for index 373 based on index 320.
# 2024-03-26 17:35:13 - INFO - Run RosettaDesign for index 374 based on index 109.
# 2024-03-26 17:36:36 - INFO - Ran ProteinMPNN for index 228 and found a new sequence with index 375.
# 2024-03-26 17:36:36 - INFO - Run ProteinMPNN for index 375 based on index 228.
# 2024-03-26 17:36:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 336.
# 2024-03-26 17:36:38 - INFO - Index 278 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:36:38 - INFO - Run ESMfold & Rosetta_Relax for index 278.
# 2024-03-26 17:36:39 - INFO - Run RosettaDesign for index 376 based on index 172.
# 2024-03-26 17:36:40 - INFO - Index 275 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:36:40 - INFO - Run ESMfold & Rosetta_Relax for index 275.
# 2024-03-26 17:36:41 - INFO - Run RosettaDesign for index 377 based on index 252.
# 2024-03-26 17:36:43 - INFO - Run RosettaDesign for index 378 based on index 287.
# 2024-03-26 17:37:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 338.
# 2024-03-26 17:37:45 - INFO - Index 312 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:37:45 - INFO - Run ESMfold & Rosetta_Relax for index 312.
# 2024-03-26 17:39:49 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 286.
# 2024-03-26 17:39:49 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 300.
# 2024-03-26 17:39:49 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 360.
# 2024-03-26 17:39:49 - INFO - Run RosettaDesign for index 379 based on index 176.
# 2024-03-26 17:39:51 - INFO - Index 259 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:39:51 - INFO - Run ESMfold & Rosetta_Relax for index 259.
# 2024-03-26 17:39:52 - INFO - Run RosettaDesign for index 380 based on index 201.
# 2024-03-26 17:40:54 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 364.
# 2024-03-26 17:42:06 - INFO - Ran ProteinMPNN for index 228 and found a new sequence with index 381.
# 2024-03-26 17:42:07 - INFO - Run ProteinMPNN for index 381 based on index 228.
# 2024-03-26 17:42:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 319.
# 2024-03-26 17:42:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 322.
# 2024-03-26 17:42:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 328.
# 2024-03-26 17:42:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 351.
# 2024-03-26 17:42:08 - INFO - Index 322 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:42:08 - INFO - Run ESMfold & Rosetta_Relax for index 322.
# 2024-03-26 17:42:10 - INFO - Run RosettaDesign for index 382 based on index 205.
# 2024-03-26 17:42:11 - INFO - Run RosettaDesign for index 383 based on index 338.
# 2024-03-26 17:42:12 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 221.
# 2024-03-26 17:42:13 - INFO - Run RosettaDesign for index 384 based on index 274.
# 2024-03-26 17:42:14 - INFO - Run RosettaDesign for index 385 based on index 274.
# 2024-03-26 17:43:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 255.
# 2024-03-26 17:43:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 269.
# 2024-03-26 17:43:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 297.
# 2024-03-26 17:43:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 318.
# 2024-03-26 17:43:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 321.
# 2024-03-26 17:43:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 323.
# 2024-03-26 17:43:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 326.
# 2024-03-26 17:43:17 - INFO - Run RosettaDesign for index 386 based on index 316.
# 2024-03-26 17:43:19 - INFO - Run RosettaDesign for index 387 based on index 284.
# 2024-03-26 17:44:59 - INFO - Ran ProteinMPNN for index 300 and found a new sequence with index 388.
# 2024-03-26 17:45:00 - INFO - Run ProteinMPNN for index 388 based on index 300.
# 2024-03-26 17:45:01 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 324.
# 2024-03-26 17:45:01 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 327.
# 2024-03-26 17:45:02 - INFO - Run RosettaDesign for index 389 based on index 197.
# 2024-03-26 17:45:05 - INFO - Run RosettaDesign for index 390 based on index 182.
# 2024-03-26 17:45:06 - INFO - Index 321 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 17:45:06 - INFO - Run ESMfold & Rosetta_Relax for index 321.
# 2024-03-26 17:45:08 - INFO - Run RosettaDesign for index 391 based on index 218.
# 2024-03-26 17:45:10 - INFO - Run RosettaDesign for index 392 based on index 316.
# 2024-03-26 17:46:42 - INFO - Ran ProteinMPNN for index 332 and found a new sequence with index 393.
# 2024-03-26 17:46:42 - INFO - Run ProteinMPNN for index 393 based on index 332.
# ...
# 2024-03-26 19:00:04 - INFO - Run RosettaDesign for index 516 based on index 210.
# 2024-03-26 19:03:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 468.
# 2024-03-26 19:03:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 483.
# 2024-03-26 19:03:09 - INFO - Run RosettaDesign for index 517 based on index 367.
# 2024-03-26 19:03:12 - INFO - Index 435 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:03:12 - INFO - Run ESMfold & Rosetta_Relax for index 435.
# 2024-03-26 19:03:13 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 328.
# 2024-03-26 19:03:13 - INFO - Run RosettaDesign for index 518 based on index 337.
# 2024-03-26 19:04:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 237.
# 2024-03-26 19:05:26 - INFO - Ran ProteinMPNN for index 348 and found a new sequence with index 519.
# 2024-03-26 19:05:26 - INFO - Run ProteinMPNN for index 519 based on index 348.
# 2024-03-26 19:05:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 454.
# 2024-03-26 19:05:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 464.
# 2024-03-26 19:05:28 - INFO - Run RosettaDesign for index 520 based on index 72.
# 2024-03-26 19:05:29 - INFO - Index 439 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:05:30 - INFO - Run ESMfold & Rosetta_Relax for index 439.
# 2024-03-26 19:06:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 451.
# 2024-03-26 19:06:32 - INFO - Run RosettaDesign for index 521 based on index 218.
# 2024-03-26 19:07:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 509.
# 2024-03-26 19:07:35 - INFO - Run RosettaDesign for index 522 based on index 235.
# 2024-03-26 19:08:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 429.
# 2024-03-26 19:08:38 - INFO - Index 392 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:08:38 - INFO - Run ESMfold & Rosetta_Relax for index 392.
# 2024-03-26 19:09:40 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 469.
# 2024-03-26 19:09:41 - INFO - Run RosettaDesign for index 523 based on index 367.
# 2024-03-26 19:09:43 - INFO - Index 288 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:09:43 - INFO - Run ESMfold & Rosetta_Relax for index 288.
# 2024-03-26 19:11:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 266.
# 2024-03-26 19:11:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 457.
# 2024-03-26 19:11:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 471.
# 2024-03-26 19:11:48 - INFO - Index 468 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:11:48 - INFO - Run ESMfold & Rosetta_Relax for index 468.
# 2024-03-26 19:13:00 - INFO - Ran ProteinMPNN for index 367 and found a new sequence with index 524.
# 2024-03-26 19:13:00 - INFO - Run ProteinMPNN for index 524 based on index 367.
# 2024-03-26 19:13:01 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 377.
# 2024-03-26 19:14:15 - INFO - Ran ProteinMPNN for index 249 and found a new sequence with index 525.
# 2024-03-26 19:14:15 - INFO - Run ProteinMPNN for index 525 based on index 249.
# 2024-03-26 19:14:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 475.
# 2024-03-26 19:14:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 496.
# 2024-03-26 19:14:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 514.
# 2024-03-26 19:14:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 515.
# 2024-03-26 19:14:18 - INFO - Run RosettaDesign for index 526 based on index 233.
# 2024-03-26 19:14:20 - INFO - Run RosettaDesign for index 527 based on index 289.
# 2024-03-26 19:14:21 - INFO - Run RosettaDesign for index 528 based on index 367.
# 2024-03-26 19:14:23 - INFO - Run RosettaDesign for index 529 based on index 451.
# 2024-03-26 19:14:25 - INFO - Run RosettaDesign for index 530 based on index 306.
# 2024-03-26 19:15:28 - INFO - Run RosettaDesign for index 531 based on index 217.
# 2024-03-26 19:16:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 474.
# 2024-03-26 19:16:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 481.
# 2024-03-26 19:16:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 506.
# 2024-03-26 19:17:44 - INFO - Ran ProteinMPNN for index 355 and found a new sequence with index 532.
# 2024-03-26 19:17:44 - INFO - Run ProteinMPNN for index 532 based on index 355.
# 2024-03-26 19:17:46 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 288.
# 2024-03-26 19:17:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 392.
# 2024-03-26 19:17:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 435.
# 2024-03-26 19:17:48 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 495.
# 2024-03-26 19:17:48 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 504.
# 2024-03-26 19:17:49 - INFO - Run RosettaDesign for index 533 based on index 94.
# 2024-03-26 19:17:51 - INFO - Index 401 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:17:51 - INFO - Run ESMfold & Rosetta_Relax for index 401.
# 2024-03-26 19:17:52 - INFO - Index 423 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:17:52 - INFO - Run ESMfold & Rosetta_Relax for index 423.
# 2024-03-26 19:19:09 - INFO - Ran ProteinMPNN for index 270 and found a new sequence with index 534.
# 2024-03-26 19:19:09 - INFO - Run ProteinMPNN for index 534 based on index 270.
# 2024-03-26 19:19:11 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 468.
# 2024-03-26 19:19:11 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 479.
# 2024-03-26 19:19:11 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 480.
# 2024-03-26 19:19:12 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 482.
# 2024-03-26 19:19:12 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 508.
# 2024-03-26 19:20:36 - INFO - Ran ProteinMPNN for index 367 and found a new sequence with index 535.
# 2024-03-26 19:20:37 - INFO - Run ProteinMPNN for index 535 based on index 367.
# 2024-03-26 19:20:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 484.
# 2024-03-26 19:20:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 487.
# 2024-03-26 19:20:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 492.
# 2024-03-26 19:20:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 494.
# 2024-03-26 19:20:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 499.
# 2024-03-26 19:20:39 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 507.
# 2024-03-26 19:20:39 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 519.
# 2024-03-26 19:20:39 - INFO - Run RosettaDesign for index 536 based on index 286.
# 2024-03-26 19:20:40 - INFO - Index 232 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:20:41 - INFO - Run ESMfold & Rosetta_Relax for index 232.
# 2024-03-26 19:20:43 - INFO - Run RosettaDesign for index 537 based on index 325.
# 2024-03-26 19:20:46 - INFO - Run RosettaDesign for index 538 based on index 465.
# 2024-03-26 19:20:48 - INFO - Run RosettaDesign for index 539 based on index 244.
# 2024-03-26 19:20:49 - INFO - Index 354 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:20:49 - INFO - Run ESMfold & Rosetta_Relax for index 354.
# 2024-03-26 19:20:51 - INFO - Run RosettaDesign for index 540 based on index 315.
# 2024-03-26 19:22:15 - INFO - Ran ProteinMPNN for index 355 and found a new sequence with index 541.
# 2024-03-26 19:22:15 - INFO - Run ProteinMPNN for index 541 based on index 355.
# 2024-03-26 19:22:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 390.
# 2024-03-26 19:22:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 477.
# 2024-03-26 19:22:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 486.
# 2024-03-26 19:22:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 512.
# 2024-03-26 19:22:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 513.
# 2024-03-26 19:22:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 525.
# 2024-03-26 19:22:19 - INFO - Index 343 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:22:19 - INFO - Run ESMfold & Rosetta_Relax for index 343.
# 2024-03-26 19:22:22 - INFO - Index 463 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:22:22 - INFO - Run ESMfold & Rosetta_Relax for index 463.
# 2024-03-26 19:22:23 - INFO - Run RosettaDesign for index 542 based on index 218.
# 2024-03-26 19:22:25 - INFO - Run RosettaDesign for index 543 based on index 350.
# 2024-03-26 19:22:27 - INFO - Run RosettaDesign for index 544 based on index 408.
# 2024-03-26 19:22:29 - INFO - Run RosettaDesign for index 545 based on index 470.
# 2024-03-26 19:22:31 - INFO - Run RosettaDesign for index 546 based on index 367.
# 2024-03-26 19:22:32 - INFO - Run RosettaDesign for index 547 based on index 319.
# 2024-03-26 19:22:34 - INFO - Run RosettaDesign for index 548 based on index 473.
# 2024-03-26 19:22:36 - INFO - Index 499 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:22:36 - INFO - Run ESMfold & Rosetta_Relax for index 499.
# 2024-03-26 19:22:37 - INFO - Index 366 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:22:38 - INFO - Run ESMfold & Rosetta_Relax for index 366.
# 2024-03-26 19:22:40 - INFO - Run RosettaDesign for index 549 based on index 244.
# 2024-03-26 19:24:02 - INFO - Ran ProteinMPNN for index 396 and found a new sequence with index 550.
# 2024-03-26 19:24:03 - INFO - Run ProteinMPNN for index 550 based on index 396.
# 2024-03-26 19:24:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 185.
# 2024-03-26 19:24:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 485.
# 2024-03-26 19:24:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 490.
# 2024-03-26 19:24:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 491.
# 2024-03-26 19:24:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 500.
# 2024-03-26 19:25:49 - INFO - Ran ProteinMPNN for index 351 and found a new sequence with index 551.
# 2024-03-26 19:25:49 - INFO - Run ProteinMPNN for index 551 based on index 351.
# 2024-03-26 19:25:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 439.
# 2024-03-26 19:25:52 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 488.
# 2024-03-26 19:25:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 489.
# 2024-03-26 19:25:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 493.
# 2024-03-26 19:25:54 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 516.
# 2024-03-26 19:25:54 - INFO - Run RosettaDesign for index 552 based on index 336.
# 2024-03-26 19:25:57 - INFO - Run RosettaDesign for index 553 based on index 268.
# 2024-03-26 19:27:16 - INFO - Ran ProteinMPNN for index 320 and found a new sequence with index 554.
# 2024-03-26 19:27:16 - INFO - Run ProteinMPNN for index 554 based on index 320.
# 2024-03-26 19:27:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 498.
# 2024-03-26 19:27:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 505.
# 2024-03-26 19:27:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 524.
# 2024-03-26 19:27:20 - INFO - Run RosettaDesign for index 555 based on index 235.
# 2024-03-26 19:27:22 - INFO - Index 426 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:27:22 - INFO - Run ESMfold & Rosetta_Relax for index 426.
# 2024-03-26 19:27:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 363.
# 2024-03-26 19:27:25 - INFO - Run RosettaDesign for index 556 based on index 183.
# 2024-03-26 19:27:28 - INFO - Run RosettaDesign for index 557 based on index 355.
# 2024-03-26 19:27:29 - INFO - Run RosettaDesign for index 558 based on index 317.
# 2024-03-26 19:27:31 - INFO - Index 405 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:27:31 - INFO - Run ESMfold & Rosetta_Relax for index 405.
# 2024-03-26 19:27:33 - INFO - Run RosettaDesign for index 559 based on index 329.
# 2024-03-26 19:27:35 - INFO - Index 492 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:27:35 - INFO - Run ESMfold & Rosetta_Relax for index 492.
# 2024-03-26 19:27:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 410.
# 2024-03-26 19:27:38 - INFO - Run RosettaDesign for index 560 based on index 470.
# 2024-03-26 19:27:40 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 346.
# 2024-03-26 19:28:56 - INFO - Ran ProteinMPNN for index 355 and found a new sequence with index 561.
# 2024-03-26 19:28:56 - INFO - Run ProteinMPNN for index 561 based on index 355.
# 2024-03-26 19:28:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 401.
# 2024-03-26 19:28:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 434.
# 2024-03-26 19:28:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 453.
# 2024-03-26 19:28:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 502.
# 2024-03-26 19:28:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 511.
# 2024-03-26 19:28:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 517.
# 2024-03-26 19:28:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 518.
# 2024-03-26 19:28:59 - INFO - Run RosettaDesign for index 562 based on index 435.
# 2024-03-26 19:29:01 - INFO - Index 293 has no relaxed structure, starting ESMfold_Rosetta_Relax.
# 2024-03-26 19:29:01 - INFO - Run ESMfold & Rosetta_Relax for index 293.
# 2024-03-26 19:30:18 - INFO - Ran ProteinMPNN for index 65 and found a new sequence with index 563.
# 2024-03-26 19:30:18 - INFO - Run ProteinMPNN for index 563 based on index 65.
# 2024-03-26 19:30:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 415.
# 2024-03-26 19:30:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 433.
# 2024-03-26 19:30:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 448.
# 2024-03-26 19:31:32 - INFO - Ran ProteinMPNN for index 317 and found a new sequence with index 564.
# 2024-03-26 19:31:33 - INFO - Run ProteinMPNN for index 564 based on index 317.
# 2024-03-26 19:31:34 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 510.
# 2024-03-26 19:31:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 520.
# 2024-03-26 19:31:35 - INFO - Run RosettaDesign for index 565 based on index 391.
# 2024-03-26 19:31:37 - INFO - Run RosettaDesign for index 566 based on index 183.
# 2024-03-26 19:31:38 - INFO - Run RosettaDesign for index 567 based on index 236.
# 2024-03-26 19:31:40 - INFO - Run RosettaDesign for index 568 based on index 408.
# 2024-03-26 19:31:41 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 532.

# %%
# !qstat | grep PMPNN
#!qstat | grep MATCH | awk '{print $1}' | xargs -I {} qdel {}

# %%
# %run "$AIZYME_TOOLS"
all_scores_df = pd.read_csv(f"{DESIGN_FOLDER}/all_scores.csv")
display(all_scores_df)

# %%
# %run "$AIZYME_TOOLS"
get_best_structures()
# Out:
# AIzyme Functions loaded!
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_8535/2690132606.py in <module>
#       1 get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
# ----> 2 get_best_structures()
#
# /tmp/ipykernel_8535/2580291326.py in get_best_structures()
#     192
#     193     # Read the scores DataFrame
# --> 194     all_scores_df = pd.read_csv('/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv')
#     195
#     196     # Drop rows with NaN in 'total_score'
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: '/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv'

# %%
# !qstat

# %%
make_empty_all_scores_df()
# Out:
# Empty DataFrame
# Columns: [index, sequence, parent_index, interface_score, total_score, catalytic_score, interface_potential, total_potential, catalytic_potential, relax_interface_score, relax_total_score, relax_catalytic_score, design_interface_score, design_total_score, design_catalytic_score, generation, mutations, design_method, score_taken_from, blocked, cat_resi, cat_resn]
# Index: []
#
# [0 rows x 22 columns]

# %%
# !qdel 859581 859582 859583 859584 859586 859587 859588 859589 859590 859594 859595 859600 859604 859610 859611 859613 859614 859615 859619 859620 859629 859632 859633 859634 859635 859636 859637 859638 859639 859640 859641 859642 859643 859644 859645 859646 859647 859648 859649 859650 859651 859652 859653 859654 859655 859656 859657 859658 859659 859660 859661 859662 859663 859664 859665 859666 859667 859668 859669 859670 859671 859672 859673 859674 859675 859676
# Out:
# lmerlicek has registered the job 859581 for deletion
# lmerlicek has registered the job 859582 for deletion
# lmerlicek has registered the job 859583 for deletion
# lmerlicek has registered the job 859584 for deletion
# lmerlicek has registered the job 859586 for deletion
# lmerlicek has registered the job 859587 for deletion
# lmerlicek has registered the job 859588 for deletion
# job 859589 is already in deletion
# lmerlicek has registered the job 859590 for deletion
# job 859594 is already in deletion
# job 859595 is already in deletion
# lmerlicek has registered the job 859600 for deletion
# denied: job "859604" does not exist
# denied: job "859610" does not exist
# lmerlicek has registered the job 859611 for deletion
# lmerlicek has registered the job 859613 for deletion
# denied: job "859614" does not exist
# lmerlicek has registered the job 859615 for deletion
# lmerlicek has registered the job 859619 for deletion
# lmerlicek has registered the job 859620 for deletion
# denied: job "859629" does not exist
# lmerlicek has registered the job 859632 for deletion
# lmerlicek has registered the job 859633 for deletion
# lmerlicek has registered the job 859634 for deletion
# lmerlicek has registered the job 859635 for deletion
# lmerlicek has registered the job 859636 for deletion
# lmerlicek has registered the job 859637 for deletion
# lmerlicek has registered the job 859638 for deletion
# lmerlicek has registered the job 859639 for deletion
# lmerlicek has registered the job 859640 for deletion
# lmerlicek has registered the job 859641 for deletion
# lmerlicek has registered the job 859642 for deletion
# lmerlicek has registered the job 859643 for deletion
# lmerlicek has registered the job 859644 for deletion
# lmerlicek has registered the job 859645 for deletion
# lmerlicek has registered the job 859646 for deletion
# lmerlicek has registered the job 859647 for deletion
# lmerlicek has registered the job 859648 for deletion
# lmerlicek has registered the job 859649 for deletion
# lmerlicek has registered the job 859650 for deletion
# lmerlicek has registered the job 859651 for deletion
# lmerlicek has registered the job 859652 for deletion
# lmerlicek has registered the job 859653 for deletion
# lmerlicek has registered the job 859654 for deletion
# lmerlicek has registered the job 859655 for deletion
# lmerlicek has registered the job 859656 for deletion
# lmerlicek has registered the job 859657 for deletion
# lmerlicek has registered the job 859658 for deletion
# lmerlicek has registered the job 859659 for deletion
# lmerlicek has registered the job 859660 for deletion
# lmerlicek has registered the job 859661 for deletion
# lmerlicek has registered the job 859662 for deletion
# lmerlicek has registered the job 859663 for deletion
# lmerlicek has registered the job 859664 for deletion
# lmerlicek has registered the job 859665 for deletion
# lmerlicek has registered the job 859666 for deletion
# lmerlicek has registered the job 859667 for deletion
# lmerlicek has registered the job 859668 for deletion
# lmerlicek has registered the job 859669 for deletion
# lmerlicek has registered the job 859670 for deletion
# lmerlicek has registered the job 859671 for deletion
# lmerlicek has registered the job 859672 for deletion
# lmerlicek has registered the job 859673 for deletion
# lmerlicek has registered the job 859674 for deletion
# lmerlicek has registered the job 859675 for deletion
# lmerlicek has registered the job 859676 for deletion
