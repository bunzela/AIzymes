# %%
""" ---------------------------------------------------------------------------------------------------------------------------
# Test script to establish AI.zymes on SCC
" -----------------------------------------------------------------------------------------------------------------------------
""" 

import sys, os
if os.path.join(os.getcwd(), '../../src') not in sys.path: sys.path.append(os.path.join(os.getcwd(), '../../src'))
from AIzymes_015 import *

# GENERAL SETTINGS FOR AI.zymes -------------------------------------------------------------------------------------------
AIzymes = AIzymes_MAIN()
AIzymes.setup(FOLDER_HOME = 'TEST_Rosetta_2',
  FOLDER_PARENT     = 'parent',
  MAX_JOBS          = 2,
  MAX_GPUS          = 0,
  MEMORY            = 200,
  N_PARENT_JOBS     = 3,
  MAX_DESIGNS       = 10,
  KBT_BOLTZMANN     = [0.5, 0.0003],
  CST_WEIGHT        = 1.0,
  CST_NAME          = "5TS_enzdes_planar_tAB100",
  WT                = "7vuu_truncated",
  LIGAND            = "5TS",
  DESIGN            = "4,8,9",
  SYSTEM            = "GRID",
  EXPLORE           = True,
  RUN_PARALLEL      = False,
  SUBMIT_PREFIX     = "TEST",
  SCORING_METHODS  = ['ESMfold','RosettaRelax','ElectricFields'], 
  SELECTED_SCORES  = ["total","catalytic","interface","efield",'identical'],
 )
# Out:
# Do you really want to restart AIzymes from scratch?
#     This will delete all existing files in /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2 [y/n]
#
#      y
# 2025-02-20 18:27:14 - INFO - Running AI.zymes setup.
# 2025-02-20 18:27:14 - INFO - Content of /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2 deleted.
# 2025-02-20 18:27:14 - INFO - Happy AI.zymeing! :)
#   sequence parent_index generation total_mutations parent_mutations  \
# 0      NaN       Parent          0             NaN              NaN
#
#   score_taken_from  design_method    blocked cat_resi cat_resn  ...  \
# 0              NaN  RosettaDesign  unblocked        8      NaN  ...
#
#   efield_score design_efield_score relax_efield_score identical_potential  \
# 0          NaN                 NaN                NaN                 NaN
#
#   identical_score design_identical_score relax_identical_score kbt_boltzmann  \
# 0             NaN                    NaN                   NaN           0.5
#
#   cst_weight                                               luca
# 0          1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta...
#
# [1 rows x 37 columns]
# 2025-02-20 18:27:14 - DEBUG - Child index 0 created for parent index Parent.
#   sequence parent_index generation total_mutations parent_mutations  \
# 0      NaN       Parent          0             NaN              NaN
# 1      NaN       Parent          0             NaN              NaN
#
#   score_taken_from  design_method    blocked cat_resi cat_resn  ...  \
# 0              NaN  RosettaDesign  unblocked        8      NaN  ...
# 1              NaN  RosettaDesign  unblocked        8      NaN  ...
#
#   efield_score design_efield_score relax_efield_score identical_potential  \
# 0          NaN                 NaN                NaN                 NaN
# 1          NaN                 NaN                NaN                 NaN
#
#   identical_score design_identical_score relax_identical_score kbt_boltzmann  \
# 0             NaN                    NaN                   NaN           0.5
# 1             NaN                    NaN                   NaN           0.5
#
#   cst_weight                                               luca
# 0          1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta...
# 1          1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta...
#
# [2 rows x 37 columns]
# 2025-02-20 18:27:14 - DEBUG - Child index 1 created for parent index Parent.
#   sequence parent_index generation total_mutations parent_mutations  \
# 0      NaN       Parent          0             NaN              NaN
# 1      NaN       Parent          0             NaN              NaN
# 2      NaN       Parent          0             NaN              NaN
#
#   score_taken_from  design_method    blocked cat_resi cat_resn  ...  \
# 0              NaN  RosettaDesign  unblocked        8      NaN  ...
# 1              NaN  RosettaDesign  unblocked        8      NaN  ...
# 2              NaN  RosettaDesign  unblocked        8      NaN  ...
#
#   efield_score design_efield_score relax_efield_score identical_potential  \
# 0          NaN                 NaN                NaN                 NaN
# 1          NaN                 NaN                NaN                 NaN
# 2          NaN                 NaN                NaN                 NaN
#
#   identical_score design_identical_score relax_identical_score kbt_boltzmann  \
# 0             NaN                    NaN                   NaN           0.5
# 1             NaN                    NaN                   NaN           0.5
# 2             NaN                    NaN                   NaN           0.5
#
#   cst_weight                                               luca
# 0          1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta...
# 1          1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta...
# 2          1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta...
#
# [3 rows x 37 columns]
# 2025-02-20 18:27:14 - DEBUG - Child index 2 created for parent index Parent.

# %%
import sys, os
if os.path.join(os.getcwd(), '../../src') not in sys.path: sys.path.append(os.path.join(os.getcwd(), '../../src'))
from AIzymes_015 import *
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)
AIzymes = AIzymes_MAIN()
AIzymes.initialize(FOLDER_HOME = 'TEST_Rosetta_2', LOG="debug", PRINT_VAR=False) 
AIzymes.controller()

# %%
# !ssh bunzelh@bs-submit04 qstat

# %%
import pandas as pd
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

file_path = "TEST_Rosetta_2/all_scores.csv"
df = pd.read_csv(file_path)

display(df)
index=2
print(df.iloc[index])
# Out:
#      sequence parent_index  generation  total_mutations  parent_mutations  \
# 0  LREEFRVEDK       Parent           0              1.0               1.0
# 1  LREEFRVEDK       Parent           0              1.0               1.0
# 2  LREEFRVEDK       Parent           0              1.0               1.0
#
#   score_taken_from  design_method    blocked  cat_resi cat_resn  \
# 0    RosettaDesign  RosettaDesign  unblocked         8      GLU
# 1    RosettaDesign  RosettaDesign    ESMfold         8      GLU
# 2    RosettaDesign  RosettaDesign    ESMfold         8      GLU
#
#                     next_steps  \
# 0                          NaN
# 1  RosettaRelax,ElectricFields
# 2  RosettaRelax,ElectricFields
#
#                                                                            final_variant  \
# 0  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/0/7vuu_truncated_RosettaDesign_0.pdb
# 1   ('/home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/1/7vuu_truncated_ESMfold_1.pdb',)
# 2   ('/home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/2/7vuu_truncated_ESMfold_2.pdb',)
#
#                                                                 input_variant  \
# 0  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
# 1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
# 2  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
#
#                                                                           latest_variant  \
# 0  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/0/7vuu_truncated_RosettaDesign_0.pdb
# 1        /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/1/7vuu_truncated_ESMfold_1.pdb
# 2        /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/2/7vuu_truncated_ESMfold_2.pdb
#
#    total_potential  total_score  design_total_score  relax_total_score  \
# 0           16.577       16.577              16.577                NaN
# 1           16.577       16.577              16.577                NaN
# 2           16.577       16.577              16.577                NaN
#
#    catalytic_potential  catalytic_score  design_catalytic_score  \
# 0                32.26            32.26                   32.26
# 1                32.26            32.26                   32.26
# 2                32.26            32.26                   32.26
#
#    relax_catalytic_score  interface_potential  interface_score  \
# 0                    NaN              -12.975          -12.975
# 1                    NaN              -12.975          -12.975
# 2                    NaN              -12.975          -12.975
#
#    design_interface_score  relax_interface_score  efield_potential  \
# 0                 -12.975                    NaN       2616.103023
# 1                 -12.975                    NaN       2616.103023
# 2                 -12.975                    NaN       2616.102845
#
#    efield_score  design_efield_score  relax_efield_score  identical_potential  \
# 0   2616.103023          2616.103023                 NaN                  1.0
# 1   2616.103023          2616.103023                 NaN                  1.0
# 2   2616.102845          2616.102845                 NaN                  1.0
#
#    identical_score  design_identical_score  relax_identical_score  \
# 0              1.0                     NaN                    NaN
# 1              1.0                     NaN                    NaN
# 2              1.0                     NaN                    NaN
#
#    kbt_boltzmann  cst_weight  \
# 0            0.5         1.0
# 1            0.5         1.0
# 2            0.5         1.0
#
#                                                                          luca
# 0  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
# 1  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
# 2  /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
# sequence                                                                                            LREEFRVEDK
# parent_index                                                                                            Parent
# generation                                                                                                   0
# total_mutations                                                                                              1
# parent_mutations                                                                                             1
# score_taken_from                                                                                 RosettaDesign
# design_method                                                                                    RosettaDesign
# blocked                                                                                                ESMfold
# cat_resi                                                                                                     8
# cat_resn                                                                                                   GLU
# next_steps                                                                         RosettaRelax,ElectricFields
# final_variant             ('/home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/2/7vuu_truncated_ESMfold_2.pdb',)
# input_variant                       /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
# latest_variant                 /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/2/7vuu_truncated_ESMfold_2.pdb
# total_potential                                                                                         16.577
# total_score                                                                                             16.577
# design_total_score                                                                                      16.577
# relax_total_score                                                                                          NaN
# catalytic_potential                                                                                      32.26
# catalytic_score                                                                                          32.26
# design_catalytic_score                                                                                   32.26
# relax_catalytic_score                                                                                      NaN
# interface_potential                                                                                    -12.975
# interface_score                                                                                        -12.975
# design_interface_score                                                                                 -12.975
# relax_interface_score                                                                                      NaN
# efield_potential                                                                                        2616.1
# efield_score                                                                                            2616.1
# design_efield_score                                                                                     2616.1
# relax_efield_score                                                                                         NaN
# identical_potential                                                                                          1
# identical_score                                                                                              1
# design_identical_score                                                                                     NaN
# relax_identical_score                                                                                      NaN
# kbt_boltzmann                                                                                              0.5
# cst_weight                                                                                                   1
# luca                                /home/bunzelh/AIzymes/design/TEST/TEST_Rosetta_2/parent/7vuu_truncated.pdb
# Name: 2, dtype: object
