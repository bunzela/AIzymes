# %% [markdown]
# ## Run function for the AIzyme algorithm, relies on the Function part

# %%
#### DESIGN RUN NAME #####################################################################################################
DESIGN_FOLDER     = 'LM_MATCH_GRID_Functions_009'
FOLDER_MATCH      = 'MATCH' #Not needed for now -> This is just for match
FOLDER_PARENT     = f'{FOLDER_MATCH}/matches' # -> Adjust, contains ONLY parent pdbs
##########################################################################################################################
#### Input parameters ####################################################################################################
MAX_JOBS          = 100
N_PARENT_JOBS     = 10
MAX_DESIGNS       = 40000
KBT_BOLTZMANN     = 0.02
CST_WEIGHT        = 1.0
HIGHSCORE         = 0.93
NEG_BEST          = 0.79
ProteinMPNN_PROB  = 0.0
WT                = "1ohp"
LIGAND            = "5TS"
REPACK            = "36,45,51,67"
MATCH             = "14,18,26,30,55,65,80,82,99,101,112"
DESIGN            = "7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78"
DESIGN           += ",80,82,84,86,93,95,97,99,101,103,109,112,114,116,121"
ProteinMPNN_T     = "0.1"
SUBMIT_PREFIX     = "MATCH" # Adjust, use a short prefix to allow 
BLUEPEBBLE        = False
GRID              = True
BACKGROUND_JOB    = False

if GRID:            ROSETTA_PATH = "/home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/"      #GRID
if BLUEPEBBLE:      
                    ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
                    BLUEPEBBLE_ACCOUNT = "ptch000361"
                    #BLUEPEBBLE_ACCOUNT = "ptch000721"
if BACKGROUND_JOB:  ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
    
NORM              = {'interface_score': [10, 30], 'total_score': [340, 410], 'catalytic_score': [-40, 0]}
##########################################################################################################################
AIZYME_TOOLS      = "../src/AIzymes_010.ipynb"
# %run "$AIZYME_TOOLS"
plot_scores()
# Out:
# AIzyme Functions loaded!
# catalytic_score [-40, 0] total_score [340, 410] interface_score [10, 30] HIGHSCORE: 0.86 Designs: 14957 Parents: 2164

# %%
# %run "$AIZYME_TOOLS"
run_RosettaMatch(EXPLORE=False)
# Out:
# AIzyme Functions loaded!
# 2024-03-22 19:03:43 - INFO - Run Rosetta_Match for index MATCH.

# %%
# %run "$AIZYME_TOOLS"
controller(RESET=False, EXPLORE=False, UNBLOCK_ALL=False, PRINT_VAR=True, PLOT_DATA=True)
# Out:
# AIzyme Functions loaded!
# DESIGN_FOLDER    : LM_MATCH_GRID_Functions_009
# FOLDER_MATCH     : MATCH
# MAX_JOBS         : 100
# N_PARENT_JOBS    : 10
# MAX_DESIGNS      : 40000
# KBT_BOLTZMANN    : 0.02
# CST_WEIGHT       : 1.0
# ProteinMPNN_PROB : 0.0
# WT               : 1ohp
# LIGAND           : 5TS
# ROSETTA_PATH     : /home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/
# REPACK           : 36,45,51,67
# DESIGN           : 7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78,80,82,84,86,93,95,97,99,101,103,109,112,114,116,121
# MATCH            : 14,18,26,30,55,65,80,82,99,101,112
# FOLDER_PARENT    : MATCH/matches
# ProteinMPNN_T    : 0.1
# SUBMIT_PREFIX    : MATCH
# BLUEPEBBLE       : False
# GRID             : True
# BACKGROUND_JOB   : False
# EXPLORE          : False
# catalytic_score [-40, 0] total_score [340, 410] interface_score [10, 30] HIGHSCORE: 0.86 Designs: 14957 Parents: 2164
# 2024-03-28 12:45:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14921.
# 2024-03-28 12:45:54 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14961.
# 2024-03-28 12:45:55 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14963.
# 2024-03-28 12:45:55 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14966.
# 2024-03-28 12:45:55 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14969.
# 2024-03-28 12:45:56 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14981.
# 2024-03-28 12:45:56 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14997.
# 2024-03-28 12:45:58 - INFO - Run RosettaDesign for index 15026 based on index UM_12_D55_58_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:46:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14950.
# 2024-03-28 12:46:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14964.
# 2024-03-28 12:46:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14973.
# 2024-03-28 12:46:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14982.
# 2024-03-28 12:46:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14996.
# 2024-03-28 12:46:23 - INFO - Run RosettaDesign for index 15027 based on index UM_12_D55_58_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:46:56 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14953.
# 2024-03-28 12:46:56 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14955.
# 2024-03-28 12:46:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14968.
# 2024-03-28 12:46:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14970.
# 2024-03-28 12:46:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14971.
# 2024-03-28 12:46:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14972.
# 2024-03-28 12:46:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14974.
# 2024-03-28 12:46:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14975.
# 2024-03-28 12:46:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14980.
# 2024-03-28 12:47:01 - INFO - Run RosettaDesign for index 15028 based on index UM_12_D55_58_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:47:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14949.
# 2024-03-28 12:47:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14988.
# 2024-03-28 12:47:37 - INFO - Run RosettaDesign for index 15029 based on index UM_12_D55_58_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:48:10 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14951.
# 2024-03-28 12:48:11 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14952.
# 2024-03-28 12:48:12 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14954.
# 2024-03-28 12:48:13 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14989.
# 2024-03-28 12:48:16 - INFO - Run RosettaDesign for index 15030 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:48:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14956.
# 2024-03-28 12:48:54 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14957.
# 2024-03-28 12:48:54 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14958.
# 2024-03-28 12:48:56 - INFO - Run RosettaDesign for index 15031 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:49:20 - INFO - Run RosettaDesign for index 15032 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:49:41 - INFO - Run RosettaDesign for index 15033 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:50:07 - INFO - Run RosettaDesign for index 15034 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:50:39 - INFO - Run RosettaDesign for index 15035 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:51:01 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14984.
# 2024-03-28 12:51:03 - INFO - Run RosettaDesign for index 15036 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:51:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15005.
# 2024-03-28 12:51:28 - INFO - Run RosettaDesign for index 15037 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:51:49 - INFO - Run RosettaDesign for index 15038 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:52:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15007.
# 2024-03-28 12:52:10 - INFO - Run RosettaDesign for index 15039 based on index UM_19_E99_78_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:52:22 - INFO - Run RosettaDesign for index 15040 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:52:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14985.
# 2024-03-28 12:52:33 - INFO - Run RosettaDesign for index 15041 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:52:44 - INFO - Run RosettaDesign for index 15042 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:52:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14998.
# 2024-03-28 12:52:58 - INFO - Run RosettaDesign for index 15043 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:53:14 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14983.
# 2024-03-28 12:53:14 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14986.
# 2024-03-28 12:53:14 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14987.
# 2024-03-28 12:53:16 - INFO - Run RosettaDesign for index 15044 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:53:32 - INFO - Run RosettaDesign for index 15045 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:53:42 - INFO - Run RosettaDesign for index 15046 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:53:49 - INFO - Run RosettaDesign for index 15047 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:53:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14990.
# 2024-03-28 12:53:59 - INFO - Run RosettaDesign for index 15048 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:54:07 - INFO - Run RosettaDesign for index 15049 based on index UM_7_D26_28_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:54:16 - INFO - Run RosettaDesign for index 15050 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:54:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14992.
# 2024-03-28 12:54:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15000.
# 2024-03-28 12:54:24 - INFO - Run RosettaDesign for index 15051 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:54:33 - INFO - Run RosettaDesign for index 15052 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:54:41 - INFO - Run RosettaDesign for index 15053 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:54:48 - INFO - Run RosettaDesign for index 15054 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:54:57 - INFO - Run RosettaDesign for index 15055 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:55:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15004.
# 2024-03-28 12:55:06 - INFO - Run RosettaDesign for index 15056 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:55:14 - INFO - Run RosettaDesign for index 15057 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:55:24 - INFO - Run RosettaDesign for index 15058 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:55:34 - INFO - Run RosettaDesign for index 15059 based on index UM_18_E112_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:55:41 - INFO - Run RosettaDesign for index 15060 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:55:48 - INFO - Run RosettaDesign for index 15061 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:55:55 - INFO - Run RosettaDesign for index 15062 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:56:03 - INFO - Run RosettaDesign for index 15063 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:56:13 - INFO - Run RosettaDesign for index 15064 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:56:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15002.
# 2024-03-28 12:56:21 - INFO - Run RosettaDesign for index 15065 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:56:34 - INFO - Run RosettaDesign for index 15066 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:56:47 - INFO - Run RosettaDesign for index 15067 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:56:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15003.
# 2024-03-28 12:56:54 - INFO - Run RosettaDesign for index 15068 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:57:01 - INFO - Run RosettaDesign for index 15069 based on index UM_11_E30_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:57:09 - INFO - Run RosettaDesign for index 15070 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:57:22 - INFO - Run RosettaDesign for index 15071 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:57:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15001.
# 2024-03-28 12:57:32 - INFO - Run RosettaDesign for index 15072 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:57:41 - INFO - Run RosettaDesign for index 15073 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:57:57 - INFO - Run RosettaDesign for index 15074 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:58:07 - INFO - Run RosettaDesign for index 15075 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:58:15 - INFO - Run RosettaDesign for index 15076 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:58:24 - INFO - Run RosettaDesign for index 15077 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:58:36 - INFO - Run RosettaDesign for index 15078 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:58:47 - INFO - Run RosettaDesign for index 15079 based on index UM_1_D14_52_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:58:59 - INFO - Run RosettaDesign for index 15080 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:59:09 - INFO - Run RosettaDesign for index 15081 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:59:20 - INFO - Run RosettaDesign for index 15082 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:59:34 - INFO - Run RosettaDesign for index 15083 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:59:45 - INFO - Run RosettaDesign for index 15084 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 12:59:54 - INFO - Run RosettaDesign for index 15085 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:00:07 - INFO - Run RosettaDesign for index 15086 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:00:17 - INFO - Run RosettaDesign for index 15087 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:00:27 - INFO - Run RosettaDesign for index 15088 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:00:38 - INFO - Run RosettaDesign for index 15089 based on index UM_12_D55_4_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:00:48 - INFO - Run RosettaDesign for index 15090 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:00:59 - INFO - Run RosettaDesign for index 15091 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:01:13 - INFO - Run RosettaDesign for index 15092 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:01:25 - INFO - Run RosettaDesign for index 15093 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:01:37 - INFO - Run RosettaDesign for index 15094 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:01:50 - INFO - Run RosettaDesign for index 15095 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:02:03 - INFO - Run RosettaDesign for index 15096 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:02:14 - INFO - Run RosettaDesign for index 15097 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:02:25 - INFO - Run RosettaDesign for index 15098 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:02:37 - INFO - Run RosettaDesign for index 15099 based on index UM_12_D55_16_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:02:51 - INFO - Run RosettaDesign for index 15100 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:03:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15015.
# 2024-03-28 13:03:05 - INFO - Run RosettaDesign for index 15101 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:03:17 - INFO - Run RosettaDesign for index 15102 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:04:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15017.
# 2024-03-28 13:04:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15019.
# 2024-03-28 13:04:50 - INFO - Run RosettaDesign for index 15103 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:05:13 - INFO - Run RosettaDesign for index 15104 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:06:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14993.
# 2024-03-28 13:06:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15012.
# 2024-03-28 13:06:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15021.
# 2024-03-28 13:06:39 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15022.
# 2024-03-28 13:06:40 - INFO - Run RosettaDesign for index 15105 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:06:50 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 14995.
# 2024-03-28 13:06:51 - INFO - Run RosettaDesign for index 15106 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:07:04 - INFO - Run RosettaDesign for index 15107 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:07:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15006.
# 2024-03-28 13:07:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15023.
# 2024-03-28 13:07:39 - INFO - Run RosettaDesign for index 15108 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:08:13 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15011.
# 2024-03-28 13:08:15 - INFO - Run RosettaDesign for index 15109 based on index UM_19_E99_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:09:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15008.
# 2024-03-28 13:09:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15009.
# 2024-03-28 13:09:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15014.
# 2024-03-28 13:09:12 - INFO - Run RosettaDesign for index 15110 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:09:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15010.
# 2024-03-28 13:09:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15024.
# 2024-03-28 13:09:32 - INFO - Run RosettaDesign for index 15111 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:10:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15013.
# 2024-03-28 13:10:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15016.
# 2024-03-28 13:10:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15025.
# 2024-03-28 13:10:07 - INFO - Run RosettaDesign for index 15112 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:10:42 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15018.
# 2024-03-28 13:10:42 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15020.
# 2024-03-28 13:10:43 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15026.
# 2024-03-28 13:10:46 - INFO - Run RosettaDesign for index 15113 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:11:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15027.
# 2024-03-28 13:11:07 - INFO - Run RosettaDesign for index 15114 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:11:26 - INFO - Run RosettaDesign for index 15115 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:12:07 - INFO - Run RosettaDesign for index 15116 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:12:32 - INFO - Run RosettaDesign for index 15117 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:12:50 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15029.
# 2024-03-28 13:12:52 - INFO - Run RosettaDesign for index 15118 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:13:25 - INFO - Run RosettaDesign for index 15119 based on index UM_6_E65_96_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:13:49 - INFO - Run RosettaDesign for index 15120 based on index UM_7_D26_66_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-28 13:14:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15030.
# 2024-03-28 13:14:08 - INFO - Run RosettaDesign for index 15121 based on index UM_7_D26_66_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.

# %%
# !qstat | grep MATCH
#!qstat | grep MATCH | awk '{print $1}' | xargs -I {} qdel {}

# %%
# %run "$AIZYME_TOOLS"
all_scores_df = pd.read_csv(f"{DESIGN_FOLDER}/all_scores.csv")
display(all_scores_df)

# %%
# %run "$AIZYME_TOOLS"
get_best_structures()
# Out:
# AIzyme Functions loaded!
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_8535/2690132606.py in <module>
#       1 get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
# ----> 2 get_best_structures()
#
# /tmp/ipykernel_8535/2580291326.py in get_best_structures()
#     192
#     193     # Read the scores DataFrame
# --> 194     all_scores_df = pd.read_csv('/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv')
#     195
#     196     # Drop rows with NaN in 'total_score'
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: '/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv'

# %%
# !qstat

# %%
make_empty_all_scores_df()
# Out:
# Empty DataFrame
# Columns: [index, sequence, parent_index, interface_score, total_score, catalytic_score, interface_potential, total_potential, catalytic_potential, relax_interface_score, relax_total_score, relax_catalytic_score, design_interface_score, design_total_score, design_catalytic_score, generation, mutations, design_method, score_taken_from, blocked, cat_resi, cat_resn]
# Index: []
#
# [0 rows x 22 columns]

# %%
# !qdel 859581 859582 859583 859584 859586 859587 859588 859589 859590 859594 859595 859600 859604 859610 859611 859613 859614 859615 859619 859620 859629 859632 859633 859634 859635 859636 859637 859638 859639 859640 859641 859642 859643 859644 859645 859646 859647 859648 859649 859650 859651 859652 859653 859654 859655 859656 859657 859658 859659 859660 859661 859662 859663 859664 859665 859666 859667 859668 859669 859670 859671 859672 859673 859674 859675 859676
# Out:
# lmerlicek has registered the job 859581 for deletion
# lmerlicek has registered the job 859582 for deletion
# lmerlicek has registered the job 859583 for deletion
# lmerlicek has registered the job 859584 for deletion
# lmerlicek has registered the job 859586 for deletion
# lmerlicek has registered the job 859587 for deletion
# lmerlicek has registered the job 859588 for deletion
# job 859589 is already in deletion
# lmerlicek has registered the job 859590 for deletion
# job 859594 is already in deletion
# job 859595 is already in deletion
# lmerlicek has registered the job 859600 for deletion
# denied: job "859604" does not exist
# denied: job "859610" does not exist
# lmerlicek has registered the job 859611 for deletion
# lmerlicek has registered the job 859613 for deletion
# denied: job "859614" does not exist
# lmerlicek has registered the job 859615 for deletion
# lmerlicek has registered the job 859619 for deletion
# lmerlicek has registered the job 859620 for deletion
# denied: job "859629" does not exist
# lmerlicek has registered the job 859632 for deletion
# lmerlicek has registered the job 859633 for deletion
# lmerlicek has registered the job 859634 for deletion
# lmerlicek has registered the job 859635 for deletion
# lmerlicek has registered the job 859636 for deletion
# lmerlicek has registered the job 859637 for deletion
# lmerlicek has registered the job 859638 for deletion
# lmerlicek has registered the job 859639 for deletion
# lmerlicek has registered the job 859640 for deletion
# lmerlicek has registered the job 859641 for deletion
# lmerlicek has registered the job 859642 for deletion
# lmerlicek has registered the job 859643 for deletion
# lmerlicek has registered the job 859644 for deletion
# lmerlicek has registered the job 859645 for deletion
# lmerlicek has registered the job 859646 for deletion
# lmerlicek has registered the job 859647 for deletion
# lmerlicek has registered the job 859648 for deletion
# lmerlicek has registered the job 859649 for deletion
# lmerlicek has registered the job 859650 for deletion
# lmerlicek has registered the job 859651 for deletion
# lmerlicek has registered the job 859652 for deletion
# lmerlicek has registered the job 859653 for deletion
# lmerlicek has registered the job 859654 for deletion
# lmerlicek has registered the job 859655 for deletion
# lmerlicek has registered the job 859656 for deletion
# lmerlicek has registered the job 859657 for deletion
# lmerlicek has registered the job 859658 for deletion
# lmerlicek has registered the job 859659 for deletion
# lmerlicek has registered the job 859660 for deletion
# lmerlicek has registered the job 859661 for deletion
# lmerlicek has registered the job 859662 for deletion
# lmerlicek has registered the job 859663 for deletion
# lmerlicek has registered the job 859664 for deletion
# lmerlicek has registered the job 859665 for deletion
# lmerlicek has registered the job 859666 for deletion
# lmerlicek has registered the job 859667 for deletion
# lmerlicek has registered the job 859668 for deletion
# lmerlicek has registered the job 859669 for deletion
# lmerlicek has registered the job 859670 for deletion
# lmerlicek has registered the job 859671 for deletion
# lmerlicek has registered the job 859672 for deletion
# lmerlicek has registered the job 859673 for deletion
# lmerlicek has registered the job 859674 for deletion
# lmerlicek has registered the job 859675 for deletion
# lmerlicek has registered the job 859676 for deletion
