# %% [markdown]
# ## Run function for the AIzyme algorithm, relies on the Function part

# %%
#### DESIGN RUN NAME #####################################################################################################
DESIGN_FOLDER     = 'LM_MATCH_GRID_Functions_009'
FOLDER_MATCH      = 'MATCH' #Not needed for now -> This is just for match
FOLDER_PARENT     = f'{FOLDER_MATCH}/matches' # -> Adjust, contains ONLY parent pdbs
##########################################################################################################################
#### Input parameters ####################################################################################################
MAX_JOBS          = 100
N_PARENT_JOBS     = 10
MAX_DESIGNS       = 40000
KBT_BOLTZMANN     = 0.02
CST_WEIGHT        = 1.0
HIGHSCORE         = 0.93
NEG_BEST          = 0.79
ProteinMPNN_PROB  = 0.0
WT                = "1ohp"
LIGAND            = "5TS"
REPACK            = "36,45,51,67"
MATCH             = "14,18,26,30,55,65,80,82,99,101,112"
DESIGN            = "7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78"
DESIGN           += ",80,82,84,86,93,95,97,99,101,103,109,112,114,116,121"
ProteinMPNN_T     = "0.1"
SUBMIT_PREFIX     = "MATCH" # Adjust, use a short prefix to allow 
BLUEPEBBLE        = False
GRID              = True
BACKGROUND_JOB    = False

if GRID:            ROSETTA_PATH = "/home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/"      #GRID
if BLUEPEBBLE:      
                    ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
                    BLUEPEBBLE_ACCOUNT = "ptch000361"
                    #BLUEPEBBLE_ACCOUNT = "ptch000721"
if BACKGROUND_JOB:  ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
    
NORM              = {'interface_score': [10, 30], 'total_score': [340, 410], 'catalytic_score': [-40, 0]}
##########################################################################################################################
AIZYME_TOOLS      = "../src/AIzymes_010.ipynb"
# %run "$AIZYME_TOOLS"
plot_scores()
# Out:
# AIzyme Functions loaded!
# catalytic_score [-40, 0] total_score [340, 410] interface_score [10, 30] HIGHSCORE: 0.76 Designs: 54 Parents: 2164

# %%
# %run "$AIZYME_TOOLS"
run_RosettaMatch(EXPLORE=False)
# Out:
# AIzyme Functions loaded!
# 2024-03-22 19:03:43 - INFO - Run Rosetta_Match for index MATCH.

# %%
# %run "$AIZYME_TOOLS"
controller(RESET=True, EXPLORE=False, UNBLOCK_ALL=False, PRINT_VAR=True, PLOT_DATA=True)
# Out:
# AIzyme Functions loaded!
# Do you really want to restart AIzymes from scratch?
# This will delete all existing files in /home/lmerlicek/AIzymes/design/LM_MATCH_GRID_Functions_009 [y/n]
#
# n
# DESIGN_FOLDER    : LM_MATCH_GRID_Functions_009
# FOLDER_MATCH     : MATCH
# MAX_JOBS         : 100
# N_PARENT_JOBS    : 10
# MAX_DESIGNS      : 40000
# KBT_BOLTZMANN    : 0.02
# CST_WEIGHT       : 1.0
# ProteinMPNN_PROB : 0.0
# WT               : 1ohp
# LIGAND           : 5TS
# ROSETTA_PATH     : /home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/
# REPACK           : 36,45,51,67
# DESIGN           : 7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78,80,82,84,86,93,95,97,99,101,103,109,112,114,116,121
# MATCH            : 14,18,26,30,55,65,80,82,99,101,112
# FOLDER_PARENT    : MATCH/matches
# ProteinMPNN_T    : 0.1
# SUBMIT_PREFIX    : MATCH
# BLUEPEBBLE       : False
# GRID             : True
# BACKGROUND_JOB   : False
# EXPLORE          : False
# catalytic_score [-40, 0] total_score [340, 410] interface_score [10, 30] HIGHSCORE: 0.76 Designs: 54 Parents: 2164
# 2024-03-25 10:08:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 0.
# 2024-03-25 10:08:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 12.
# 2024-03-25 10:08:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 15.
# 2024-03-25 10:08:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 19.
# 2024-03-25 10:08:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 30.
# 2024-03-25 10:08:19 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 31.
# 2024-03-25 10:08:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 32.
# 2024-03-25 10:08:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 33.
# 2024-03-25 10:08:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 34.
# 2024-03-25 10:08:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 35.
# 2024-03-25 10:08:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 36.
# 2024-03-25 10:08:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 37.
# 2024-03-25 10:08:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 38.
# 2024-03-25 10:08:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 39.
# 2024-03-25 10:08:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 41.
# 2024-03-25 10:08:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 42.
# 2024-03-25 10:08:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 43.
# 2024-03-25 10:08:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 44.
# 2024-03-25 10:08:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 45.
# 2024-03-25 10:08:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 46.
# 2024-03-25 10:08:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 49.
# 2024-03-25 10:08:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 50.
# 2024-03-25 10:08:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 52.
# 2024-03-25 10:08:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 54.
# 2024-03-25 10:08:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 59.
# 2024-03-25 10:08:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 66.
# 2024-03-25 10:08:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 67.
# 2024-03-25 10:08:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 69.
# 2024-03-25 10:08:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 70.
# 2024-03-25 10:08:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 72.
# 2024-03-25 10:08:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 73.
# 2024-03-25 10:08:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 74.
# 2024-03-25 10:08:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 77.
# 2024-03-25 10:08:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 79.
# 2024-03-25 10:08:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 80.
# 2024-03-25 10:08:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 81.
# 2024-03-25 10:08:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 82.
# 2024-03-25 10:08:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 84.
# 2024-03-25 10:08:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 85.
# 2024-03-25 10:08:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 86.
# 2024-03-25 10:08:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 89.
# 2024-03-25 10:08:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 90.
# 2024-03-25 10:08:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 92.
# 2024-03-25 10:08:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 93.
# 2024-03-25 10:08:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 95.
# 2024-03-25 10:08:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 98.
# 2024-03-25 10:08:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 100.
# 2024-03-25 10:08:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 101.
# 2024-03-25 10:08:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 102.
# 2024-03-25 10:08:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 103.
# 2024-03-25 10:08:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 104.
# 2024-03-25 10:08:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 105.
# 2024-03-25 10:08:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 106.
# 2024-03-25 10:08:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 107.
# 2024-03-25 10:08:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 108.
# 2024-03-25 10:08:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 109.
# 2024-03-25 10:08:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 110.
# 2024-03-25 10:08:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 111.
# 2024-03-25 10:08:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 112.
# 2024-03-25 10:08:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 113.
# 2024-03-25 10:08:29 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 114.
# 2024-03-25 10:08:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 115.
# 2024-03-25 10:08:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 116.
# 2024-03-25 10:08:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 117.
# 2024-03-25 10:08:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 118.
# 2024-03-25 10:08:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 119.
# 2024-03-25 10:08:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 120.
# 2024-03-25 10:08:30 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 121.
# 2024-03-25 10:08:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 122.
# 2024-03-25 10:08:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 123.
# 2024-03-25 10:08:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 124.
# 2024-03-25 10:08:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 125.
# 2024-03-25 10:08:31 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 126.
# 2024-03-25 10:08:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 127.
# 2024-03-25 10:08:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 128.
# 2024-03-25 10:08:32 - INFO - Run RosettaDesign for index 129 based on index UM_4_D65_51_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:34 - INFO - Run RosettaDesign for index 130 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:35 - INFO - Run RosettaDesign for index 131 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:36 - INFO - Run RosettaDesign for index 132 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:38 - INFO - Run RosettaDesign for index 133 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:39 - INFO - Run RosettaDesign for index 134 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:41 - INFO - Run RosettaDesign for index 135 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:42 - INFO - Run RosettaDesign for index 136 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:44 - INFO - Run RosettaDesign for index 137 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:45 - INFO - Run RosettaDesign for index 138 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:47 - INFO - Run RosettaDesign for index 139 based on index UM_10_D30_26_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:48 - INFO - Run RosettaDesign for index 140 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:49 - INFO - Run RosettaDesign for index 141 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:51 - INFO - Run RosettaDesign for index 142 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:52 - INFO - Run RosettaDesign for index 143 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:55 - INFO - Run RosettaDesign for index 144 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:08:58 - INFO - Run RosettaDesign for index 145 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:00 - INFO - Run RosettaDesign for index 146 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:03 - INFO - Run RosettaDesign for index 147 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:05 - INFO - Run RosettaDesign for index 148 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:09 - INFO - Run RosettaDesign for index 149 based on index UM_18_E112_148_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:13 - INFO - Run RosettaDesign for index 150 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:16 - INFO - Run RosettaDesign for index 151 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:18 - INFO - Run RosettaDesign for index 152 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:20 - INFO - Run RosettaDesign for index 153 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:21 - INFO - Run RosettaDesign for index 154 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:23 - INFO - Run RosettaDesign for index 155 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:24 - INFO - Run RosettaDesign for index 156 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:26 - INFO - Run RosettaDesign for index 157 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:28 - INFO - Run RosettaDesign for index 158 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:29 - INFO - Run RosettaDesign for index 159 based on index UM_20_D101_8_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:31 - INFO - Run RosettaDesign for index 160 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:32 - INFO - Run RosettaDesign for index 161 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:33 - INFO - Run RosettaDesign for index 162 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:35 - INFO - Run RosettaDesign for index 163 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:36 - INFO - Run RosettaDesign for index 164 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:38 - INFO - Run RosettaDesign for index 165 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:39 - INFO - Run RosettaDesign for index 166 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:41 - INFO - Run RosettaDesign for index 167 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:43 - INFO - Run RosettaDesign for index 168 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:50 - INFO - Run RosettaDesign for index 169 based on index UM_15_D82_18_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:57 - INFO - Run RosettaDesign for index 170 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:09:59 - INFO - Run RosettaDesign for index 171 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:01 - INFO - Run RosettaDesign for index 172 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:02 - INFO - Run RosettaDesign for index 173 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:04 - INFO - Run RosettaDesign for index 174 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:06 - INFO - Run RosettaDesign for index 175 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:09 - INFO - Run RosettaDesign for index 176 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:11 - INFO - Run RosettaDesign for index 177 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:14 - INFO - Run RosettaDesign for index 178 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:15 - INFO - Run RosettaDesign for index 179 based on index UM_9_E55_127_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:16 - INFO - Run RosettaDesign for index 180 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:18 - INFO - Run RosettaDesign for index 181 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:19 - INFO - Run RosettaDesign for index 182 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:21 - INFO - Run RosettaDesign for index 183 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:22 - INFO - Run RosettaDesign for index 184 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:23 - INFO - Run RosettaDesign for index 185 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:25 - INFO - Run RosettaDesign for index 186 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:26 - INFO - Run RosettaDesign for index 187 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:27 - INFO - Run RosettaDesign for index 188 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:29 - INFO - Run RosettaDesign for index 189 based on index UM_9_E55_36_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:30 - INFO - Run RosettaDesign for index 190 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:32 - INFO - Run RosettaDesign for index 191 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:33 - INFO - Run RosettaDesign for index 192 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:34 - INFO - Run RosettaDesign for index 193 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:36 - INFO - Run RosettaDesign for index 194 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:37 - INFO - Run RosettaDesign for index 195 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:38 - INFO - Run RosettaDesign for index 196 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:40 - INFO - Run RosettaDesign for index 197 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:41 - INFO - Run RosettaDesign for index 198 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:43 - INFO - Run RosettaDesign for index 199 based on index UM_16_E82_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:44 - INFO - Run RosettaDesign for index 200 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:45 - INFO - Run RosettaDesign for index 201 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:47 - INFO - Run RosettaDesign for index 202 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:48 - INFO - Run RosettaDesign for index 203 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:49 - INFO - Run RosettaDesign for index 204 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:51 - INFO - Run RosettaDesign for index 205 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:52 - INFO - Run RosettaDesign for index 206 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:54 - INFO - Run RosettaDesign for index 207 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:55 - INFO - Run RosettaDesign for index 208 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:56 - INFO - Run RosettaDesign for index 209 based on index UM_2_E14_85_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:58 - INFO - Run RosettaDesign for index 210 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:10:59 - INFO - Run RosettaDesign for index 211 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:01 - INFO - Run RosettaDesign for index 212 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:02 - INFO - Run RosettaDesign for index 213 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:03 - INFO - Run RosettaDesign for index 214 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:05 - INFO - Run RosettaDesign for index 215 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:06 - INFO - Run RosettaDesign for index 216 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:07 - INFO - Run RosettaDesign for index 217 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:09 - INFO - Run RosettaDesign for index 218 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:10 - INFO - Run RosettaDesign for index 219 based on index UM_17_D99_95_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:12 - INFO - Run RosettaDesign for index 220 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:13 - INFO - Run RosettaDesign for index 221 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:14 - INFO - Run RosettaDesign for index 222 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:16 - INFO - Run RosettaDesign for index 223 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:17 - INFO - Run RosettaDesign for index 224 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:18 - INFO - Run RosettaDesign for index 225 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:20 - INFO - Run RosettaDesign for index 226 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:21 - INFO - Run RosettaDesign for index 227 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:11:23 - INFO - Run RosettaDesign for index 228 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:32:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 144.
# 2024-03-25 10:32:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 145.
# 2024-03-25 10:32:47 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 146.
# 2024-03-25 10:32:48 - INFO - Run RosettaDesign for index 229 based on index UM_5_E18_56_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:32:49 - INFO - Run RosettaDesign for index 230 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:32:50 - INFO - Run RosettaDesign for index 231 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:33:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 140.
# 2024-03-25 10:33:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 141.
# 2024-03-25 10:33:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 143.
# 2024-03-25 10:33:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 154.
# 2024-03-25 10:33:54 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 155.
# 2024-03-25 10:33:54 - INFO - Run RosettaDesign for index 232 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:33:55 - INFO - Run RosettaDesign for index 233 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:33:57 - INFO - Run RosettaDesign for index 234 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:33:58 - INFO - Run RosettaDesign for index 235 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:34:00 - INFO - Run RosettaDesign for index 236 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 133.
# 2024-03-25 10:35:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 134.
# 2024-03-25 10:35:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 137.
# 2024-03-25 10:35:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 142.
# 2024-03-25 10:35:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 147.
# 2024-03-25 10:35:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 148.
# 2024-03-25 10:35:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 149.
# 2024-03-25 10:35:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 150.
# 2024-03-25 10:35:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 151.
# 2024-03-25 10:35:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 152.
# 2024-03-25 10:35:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 153.
# 2024-03-25 10:35:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 157.
# 2024-03-25 10:35:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 158.
# 2024-03-25 10:35:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 159.
# 2024-03-25 10:35:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 160.
# 2024-03-25 10:35:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 161.
# 2024-03-25 10:35:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 163.
# 2024-03-25 10:35:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 167.
# 2024-03-25 10:35:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 190.
# 2024-03-25 10:35:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 193.
# 2024-03-25 10:35:05 - INFO - Run RosettaDesign for index 237 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:07 - INFO - Run RosettaDesign for index 238 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 168.
# 2024-03-25 10:35:08 - INFO - Run RosettaDesign for index 239 based on index UM_18_E112_14_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:10 - INFO - Run RosettaDesign for index 240 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:11 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 132.
# 2024-03-25 10:35:11 - INFO - Run RosettaDesign for index 241 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:12 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 162.
# 2024-03-25 10:35:13 - INFO - Run RosettaDesign for index 242 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:14 - INFO - Run RosettaDesign for index 243 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:15 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 131.
# 2024-03-25 10:35:16 - INFO - Run RosettaDesign for index 244 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 164.
# 2024-03-25 10:35:17 - INFO - Run RosettaDesign for index 245 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 135.
# 2024-03-25 10:35:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 156.
# 2024-03-25 10:35:19 - INFO - Run RosettaDesign for index 246 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:20 - INFO - Run RosettaDesign for index 247 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 139.
# 2024-03-25 10:35:22 - INFO - Run RosettaDesign for index 248 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:23 - INFO - Run RosettaDesign for index 249 based on index UM_12_D55_45_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 191.
# 2024-03-25 10:35:25 - INFO - Run RosettaDesign for index 250 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 196.
# 2024-03-25 10:35:26 - INFO - Run RosettaDesign for index 251 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:28 - INFO - Run RosettaDesign for index 252 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:29 - INFO - Run RosettaDesign for index 253 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:31 - INFO - Run RosettaDesign for index 254 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:32 - INFO - Run RosettaDesign for index 255 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:33 - INFO - Run RosettaDesign for index 256 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 136.
# 2024-03-25 10:35:35 - INFO - Run RosettaDesign for index 257 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:36 - INFO - Run RosettaDesign for index 258 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:38 - INFO - Run RosettaDesign for index 259 based on index UM_7_D26_35_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:39 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 216.
# 2024-03-25 10:35:39 - INFO - Run RosettaDesign for index 260 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:41 - INFO - Run RosettaDesign for index 261 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:42 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 169.
# 2024-03-25 10:35:42 - INFO - Run RosettaDesign for index 262 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:44 - INFO - Run RosettaDesign for index 263 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 138.
# 2024-03-25 10:35:45 - INFO - Run RosettaDesign for index 264 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:47 - INFO - Run RosettaDesign for index 265 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:48 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 165.
# 2024-03-25 10:35:48 - INFO - Run RosettaDesign for index 266 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:49 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 223.
# 2024-03-25 10:35:50 - INFO - Run RosettaDesign for index 267 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 215.
# 2024-03-25 10:35:51 - INFO - Run RosettaDesign for index 268 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:53 - INFO - Run RosettaDesign for index 269 based on index UM_14_E80_5_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:54 - INFO - Run RosettaDesign for index 270 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:56 - INFO - Run RosettaDesign for index 271 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 181.
# 2024-03-25 10:35:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 207.
# 2024-03-25 10:35:57 - INFO - Run RosettaDesign for index 272 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:35:59 - INFO - Run RosettaDesign for index 273 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:36:00 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 166.
# 2024-03-25 10:36:00 - INFO - Run RosettaDesign for index 274 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:36:02 - INFO - Run RosettaDesign for index 275 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:36:03 - INFO - Run RosettaDesign for index 276 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:05 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 129.
# 2024-03-25 10:37:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 176.
# 2024-03-25 10:37:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 178.
# 2024-03-25 10:37:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 182.
# 2024-03-25 10:37:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 183.
# 2024-03-25 10:37:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 184.
# 2024-03-25 10:37:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 185.
# 2024-03-25 10:37:06 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 186.
# 2024-03-25 10:37:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 187.
# 2024-03-25 10:37:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 188.
# 2024-03-25 10:37:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 192.
# 2024-03-25 10:37:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 197.
# 2024-03-25 10:37:07 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 198.
# 2024-03-25 10:37:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 202.
# 2024-03-25 10:37:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 210.
# 2024-03-25 10:37:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 224.
# 2024-03-25 10:37:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 227.
# 2024-03-25 10:37:08 - INFO - Run RosettaDesign for index 277 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:10 - INFO - Run RosettaDesign for index 278 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:11 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 130.
# 2024-03-25 10:37:11 - INFO - Run RosettaDesign for index 279 based on index UM_19_E99_65_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:13 - INFO - Run RosettaDesign for index 280 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:14 - INFO - Run RosettaDesign for index 281 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:16 - INFO - Run RosettaDesign for index 282 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:17 - INFO - Run RosettaDesign for index 283 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:18 - INFO - Run RosettaDesign for index 284 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 194.
# 2024-03-25 10:37:20 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 213.
# 2024-03-25 10:37:20 - INFO - Run RosettaDesign for index 285 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 211.
# 2024-03-25 10:37:21 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 212.
# 2024-03-25 10:37:22 - INFO - Run RosettaDesign for index 286 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:24 - INFO - Run RosettaDesign for index 287 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:25 - INFO - Run RosettaDesign for index 288 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:26 - INFO - Run RosettaDesign for index 289 based on index UM_18_E112_71_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 179.
# 2024-03-25 10:37:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 208.
# 2024-03-25 10:37:28 - INFO - Run RosettaDesign for index 290 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:30 - INFO - Run RosettaDesign for index 291 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:31 - INFO - Run RosettaDesign for index 292 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 203.
# 2024-03-25 10:37:33 - INFO - Run RosettaDesign for index 293 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:34 - INFO - Run RosettaDesign for index 294 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 201.
# 2024-03-25 10:37:35 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 214.
# 2024-03-25 10:37:36 - INFO - Run RosettaDesign for index 295 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:37 - INFO - Run RosettaDesign for index 296 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:38 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 218.
# 2024-03-25 10:37:39 - INFO - Run RosettaDesign for index 297 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:40 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 219.
# 2024-03-25 10:37:40 - INFO - Run RosettaDesign for index 298 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:42 - INFO - Run RosettaDesign for index 299 based on index UM_5_E18_33_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:43 - INFO - Run RosettaDesign for index 300 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:44 - INFO - Run RosettaDesign for index 301 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:46 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 189.
# 2024-03-25 10:37:46 - INFO - Run RosettaDesign for index 302 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:48 - INFO - Run RosettaDesign for index 303 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:49 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 217.
# 2024-03-25 10:37:49 - INFO - Run RosettaDesign for index 304 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:50 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 180.
# 2024-03-25 10:37:51 - INFO - Run RosettaDesign for index 305 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:52 - INFO - Run RosettaDesign for index 306 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:53 - INFO - Run RosettaDesign for index 307 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:37:55 - INFO - Run RosettaDesign for index 308 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:38:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 170.
# 2024-03-25 10:38:57 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 171.
# 2024-03-25 10:38:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 174.
# 2024-03-25 10:38:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 177.
# 2024-03-25 10:38:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 195.
# 2024-03-25 10:38:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 199.
# 2024-03-25 10:38:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 200.
# 2024-03-25 10:38:58 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 204.
# 2024-03-25 10:38:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 205.
# 2024-03-25 10:38:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 206.
# 2024-03-25 10:38:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 209.
# 2024-03-25 10:38:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 220.
# 2024-03-25 10:38:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 221.
# 2024-03-25 10:38:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 222.
# 2024-03-25 10:39:00 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 225.
# 2024-03-25 10:39:00 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 226.
# 2024-03-25 10:39:00 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 228.
# 2024-03-25 10:39:00 - INFO - Run RosettaDesign for index 309 based on index UM_10_D30_7_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:02 - INFO - Run RosettaDesign for index 310 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:03 - INFO - Run RosettaDesign for index 311 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:05 - INFO - Run RosettaDesign for index 312 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:06 - INFO - Run RosettaDesign for index 313 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:07 - INFO - Run RosettaDesign for index 314 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:09 - INFO - Run RosettaDesign for index 315 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:10 - INFO - Run RosettaDesign for index 316 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:12 - INFO - Run RosettaDesign for index 317 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:13 - INFO - Run RosettaDesign for index 318 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:14 - INFO - Run RosettaDesign for index 319 based on index UM_1_D14_64_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 172.
# 2024-03-25 10:39:16 - INFO - Run RosettaDesign for index 320 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:18 - INFO - Run RosettaDesign for index 321 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:19 - INFO - Run RosettaDesign for index 322 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:20 - INFO - Run RosettaDesign for index 323 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:22 - INFO - Run RosettaDesign for index 324 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:23 - INFO - Run RosettaDesign for index 325 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:39:25 - INFO - Run RosettaDesign for index 326 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:40:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 173.
# 2024-03-25 10:40:27 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 175.
# 2024-03-25 10:40:27 - INFO - Run RosettaDesign for index 327 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:40:29 - INFO - Run RosettaDesign for index 328 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:57:48 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 230.
# 2024-03-25 10:57:49 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 231.
# 2024-03-25 10:57:49 - INFO - Run RosettaDesign for index 329 based on index UM_12_D55_20_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:57:50 - INFO - Run RosettaDesign for index 330 based on index UM_9_E55_99_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-25 10:58:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 229.
# 2024-03-25 10:58:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 232.
# 2024-03-25 10:58:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 235.
# 2024-03-25 10:58:53 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 236.
# ...
# 2024-03-26 10:06:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5514.
# 2024-03-26 10:06:36 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5517.
# 2024-03-26 10:06:37 - INFO - Run RosettaDesign for index 5608 based on index UM_9_E55_3_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:06:40 - INFO - Run RosettaDesign for index 5609 based on index UM_9_E55_3_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:06:43 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5518.
# 2024-03-26 10:06:43 - INFO - Run RosettaDesign for index 5610 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:06:46 - INFO - Run RosettaDesign for index 5611 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:06:49 - INFO - Run RosettaDesign for index 5612 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:06:52 - INFO - Run RosettaDesign for index 5613 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:06:55 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5520.
# 2024-03-26 10:06:56 - INFO - Run RosettaDesign for index 5614 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:06:59 - INFO - Run RosettaDesign for index 5615 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:07:01 - INFO - Run RosettaDesign for index 5616 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:07:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5521.
# 2024-03-26 10:07:04 - INFO - Run RosettaDesign for index 5617 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:07:07 - INFO - Run RosettaDesign for index 5618 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:07:10 - INFO - Run RosettaDesign for index 5619 based on index UM_9_E55_57_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:08:15 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5515.
# 2024-03-26 10:08:15 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5522.
# 2024-03-26 10:08:16 - INFO - Run RosettaDesign for index 5620 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:08:19 - INFO - Run RosettaDesign for index 5621 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:09:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5519.
# 2024-03-26 10:09:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5523.
# 2024-03-26 10:09:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5524.
# 2024-03-26 10:09:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5525.
# 2024-03-26 10:09:24 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5526.
# 2024-03-26 10:09:25 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5528.
# 2024-03-26 10:09:25 - INFO - Run RosettaDesign for index 5622 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:09:28 - INFO - Run RosettaDesign for index 5623 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:09:31 - INFO - Run RosettaDesign for index 5624 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:09:34 - INFO - Run RosettaDesign for index 5625 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:09:37 - INFO - Run RosettaDesign for index 5626 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:09:40 - INFO - Run RosettaDesign for index 5627 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:10:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5527.
# 2024-03-26 10:10:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5529.
# 2024-03-26 10:10:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5533.
# 2024-03-26 10:10:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5534.
# 2024-03-26 10:10:46 - INFO - Run RosettaDesign for index 5628 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:10:49 - INFO - Run RosettaDesign for index 5629 based on index UM_18_E112_129_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:10:52 - INFO - Run RosettaDesign for index 5630 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:10:54 - INFO - Run RosettaDesign for index 5631 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:12:02 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5536.
# 2024-03-26 10:12:03 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5538.
# 2024-03-26 10:12:04 - INFO - Run RosettaDesign for index 5632 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:12:07 - INFO - Run RosettaDesign for index 5633 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5531.
# 2024-03-26 10:13:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5532.
# 2024-03-26 10:13:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5535.
# 2024-03-26 10:13:17 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5537.
# 2024-03-26 10:13:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5539.
# 2024-03-26 10:13:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5550.
# 2024-03-26 10:13:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5552.
# 2024-03-26 10:13:18 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5553.
# 2024-03-26 10:13:19 - INFO - Run RosettaDesign for index 5634 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:22 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5530.
# 2024-03-26 10:13:23 - INFO - Run RosettaDesign for index 5635 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:26 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5540.
# 2024-03-26 10:13:27 - INFO - Run RosettaDesign for index 5636 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:30 - INFO - Run RosettaDesign for index 5637 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:34 - INFO - Run RosettaDesign for index 5638 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:38 - INFO - Run RosettaDesign for index 5639 based on index UM_9_E55_146_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:41 - INFO - Run RosettaDesign for index 5640 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5541.
# 2024-03-26 10:13:45 - INFO - Run RosettaDesign for index 5641 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:49 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5546.
# 2024-03-26 10:13:49 - INFO - Run RosettaDesign for index 5642 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:53 - INFO - Run RosettaDesign for index 5643 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:13:57 - INFO - Run RosettaDesign for index 5644 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:14:00 - INFO - Run RosettaDesign for index 5645 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5542.
# 2024-03-26 10:15:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5543.
# 2024-03-26 10:15:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5551.
# 2024-03-26 10:15:09 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5554.
# 2024-03-26 10:15:10 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5555.
# 2024-03-26 10:15:10 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5557.
# 2024-03-26 10:15:10 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5559.
# 2024-03-26 10:15:11 - INFO - Run RosettaDesign for index 5646 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:15 - INFO - Run RosettaDesign for index 5647 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:18 - INFO - Run RosettaDesign for index 5648 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:22 - INFO - Run RosettaDesign for index 5649 based on index UM_10_D30_47_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:26 - INFO - Run RosettaDesign for index 5650 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:30 - INFO - Run RosettaDesign for index 5651 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:34 - INFO - Run RosettaDesign for index 5652 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:15:37 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5548.
# 2024-03-26 10:15:38 - INFO - Run RosettaDesign for index 5653 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:16:45 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5544.
# 2024-03-26 10:16:46 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5545.
# 2024-03-26 10:16:46 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5547.
# 2024-03-26 10:16:46 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5556.
# 2024-03-26 10:16:46 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5558.
# 2024-03-26 10:16:47 - INFO - Run RosettaDesign for index 5654 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:16:51 - INFO - Run RosettaDesign for index 5655 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:16:54 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5549.
# 2024-03-26 10:16:55 - INFO - Run RosettaDesign for index 5656 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:16:59 - INFO - Run RosettaDesign for index 5657 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:17:02 - INFO - Run RosettaDesign for index 5658 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:17:06 - INFO - Run RosettaDesign for index 5659 based on index UM_8_E26_115_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:18:15 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5561.
# 2024-03-26 10:18:15 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5564.
# 2024-03-26 10:18:17 - INFO - Run RosettaDesign for index 5660 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:18:20 - INFO - Run RosettaDesign for index 5661 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:19:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5560.
# 2024-03-26 10:19:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5562.
# 2024-03-26 10:19:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5563.
# 2024-03-26 10:19:28 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5565.
# 2024-03-26 10:19:29 - INFO - Run RosettaDesign for index 5662 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:19:32 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5566.
# 2024-03-26 10:19:33 - INFO - Run RosettaDesign for index 5663 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:19:37 - INFO - Run RosettaDesign for index 5664 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:19:40 - INFO - Run RosettaDesign for index 5665 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:19:44 - INFO - Run RosettaDesign for index 5666 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:20:51 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5574.
# 2024-03-26 10:20:51 - INFO - Run RosettaDesign for index 5667 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:21:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5568.
# 2024-03-26 10:21:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5570.
# 2024-03-26 10:21:59 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5571.
# 2024-03-26 10:22:00 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5573.
# 2024-03-26 10:22:01 - INFO - Run RosettaDesign for index 5668 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:22:04 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5567.
# 2024-03-26 10:22:05 - INFO - Run RosettaDesign for index 5669 based on index UM_4_D65_9_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:22:08 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5572.
# 2024-03-26 10:22:09 - INFO - Run RosettaDesign for index 5670 based on index UM_4_D65_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:22:12 - INFO - Run RosettaDesign for index 5671 based on index UM_4_D65_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:22:16 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5575.
# 2024-03-26 10:22:16 - INFO - Run RosettaDesign for index 5672 based on index UM_4_D65_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:22:20 - INFO - Run RosettaDesign for index 5673 based on index UM_4_D65_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:22:23 - INFO - Updated total_score, interface_delta_X, and catalytic_score of index 5569.
# 2024-03-26 10:22:24 - INFO - Run RosettaDesign for index 5674 based on index UM_4_D65_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.
# 2024-03-26 10:22:28 - INFO - Run RosettaDesign for index 5675 based on index UM_4_D65_30_1ohp_Rosetta_Relax_aligned_MATCH_APO_5TS_enzdes_1.

# %%
# !qstat | grep MATCH
#!qstat | grep MATCH | awk '{print $1}' | xargs -I {} qdel {}

# %%
# %run "$AIZYME_TOOLS"
all_scores_df = pd.read_csv(f"{DESIGN_FOLDER}/all_scores.csv")
display(all_scores_df)

# %%
# %run "$AIZYME_TOOLS"
get_best_structures()
# Out:
# AIzyme Functions loaded!
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_8535/2690132606.py in <module>
#       1 get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
# ----> 2 get_best_structures()
#
# /tmp/ipykernel_8535/2580291326.py in get_best_structures()
#     192
#     193     # Read the scores DataFrame
# --> 194     all_scores_df = pd.read_csv('/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv')
#     195
#     196     # Drop rows with NaN in 'total_score'
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: '/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv'

# %%
# !qstat

# %%
make_empty_all_scores_df()
# Out:
# Empty DataFrame
# Columns: [index, sequence, parent_index, interface_score, total_score, catalytic_score, interface_potential, total_potential, catalytic_potential, relax_interface_score, relax_total_score, relax_catalytic_score, design_interface_score, design_total_score, design_catalytic_score, generation, mutations, design_method, score_taken_from, blocked, cat_resi, cat_resn]
# Index: []
#
# [0 rows x 22 columns]

# %%
# !qdel 859581 859582 859583 859584 859586 859587 859588 859589 859590 859594 859595 859600 859604 859610 859611 859613 859614 859615 859619 859620 859629 859632 859633 859634 859635 859636 859637 859638 859639 859640 859641 859642 859643 859644 859645 859646 859647 859648 859649 859650 859651 859652 859653 859654 859655 859656 859657 859658 859659 859660 859661 859662 859663 859664 859665 859666 859667 859668 859669 859670 859671 859672 859673 859674 859675 859676
# Out:
# lmerlicek has registered the job 859581 for deletion
# lmerlicek has registered the job 859582 for deletion
# lmerlicek has registered the job 859583 for deletion
# lmerlicek has registered the job 859584 for deletion
# lmerlicek has registered the job 859586 for deletion
# lmerlicek has registered the job 859587 for deletion
# lmerlicek has registered the job 859588 for deletion
# job 859589 is already in deletion
# lmerlicek has registered the job 859590 for deletion
# job 859594 is already in deletion
# job 859595 is already in deletion
# lmerlicek has registered the job 859600 for deletion
# denied: job "859604" does not exist
# denied: job "859610" does not exist
# lmerlicek has registered the job 859611 for deletion
# lmerlicek has registered the job 859613 for deletion
# denied: job "859614" does not exist
# lmerlicek has registered the job 859615 for deletion
# lmerlicek has registered the job 859619 for deletion
# lmerlicek has registered the job 859620 for deletion
# denied: job "859629" does not exist
# lmerlicek has registered the job 859632 for deletion
# lmerlicek has registered the job 859633 for deletion
# lmerlicek has registered the job 859634 for deletion
# lmerlicek has registered the job 859635 for deletion
# lmerlicek has registered the job 859636 for deletion
# lmerlicek has registered the job 859637 for deletion
# lmerlicek has registered the job 859638 for deletion
# lmerlicek has registered the job 859639 for deletion
# lmerlicek has registered the job 859640 for deletion
# lmerlicek has registered the job 859641 for deletion
# lmerlicek has registered the job 859642 for deletion
# lmerlicek has registered the job 859643 for deletion
# lmerlicek has registered the job 859644 for deletion
# lmerlicek has registered the job 859645 for deletion
# lmerlicek has registered the job 859646 for deletion
# lmerlicek has registered the job 859647 for deletion
# lmerlicek has registered the job 859648 for deletion
# lmerlicek has registered the job 859649 for deletion
# lmerlicek has registered the job 859650 for deletion
# lmerlicek has registered the job 859651 for deletion
# lmerlicek has registered the job 859652 for deletion
# lmerlicek has registered the job 859653 for deletion
# lmerlicek has registered the job 859654 for deletion
# lmerlicek has registered the job 859655 for deletion
# lmerlicek has registered the job 859656 for deletion
# lmerlicek has registered the job 859657 for deletion
# lmerlicek has registered the job 859658 for deletion
# lmerlicek has registered the job 859659 for deletion
# lmerlicek has registered the job 859660 for deletion
# lmerlicek has registered the job 859661 for deletion
# lmerlicek has registered the job 859662 for deletion
# lmerlicek has registered the job 859663 for deletion
# lmerlicek has registered the job 859664 for deletion
# lmerlicek has registered the job 859665 for deletion
# lmerlicek has registered the job 859666 for deletion
# lmerlicek has registered the job 859667 for deletion
# lmerlicek has registered the job 859668 for deletion
# lmerlicek has registered the job 859669 for deletion
# lmerlicek has registered the job 859670 for deletion
# lmerlicek has registered the job 859671 for deletion
# lmerlicek has registered the job 859672 for deletion
# lmerlicek has registered the job 859673 for deletion
# lmerlicek has registered the job 859674 for deletion
# lmerlicek has registered the job 859675 for deletion
# lmerlicek has registered the job 859676 for deletion
