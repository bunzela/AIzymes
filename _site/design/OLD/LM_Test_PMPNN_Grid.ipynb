# %% [markdown]
# ## Run function for the AIzyme algorithm, relies on the Function part

# %%
#### DESIGN RUN NAME #####################################################################################################
DESIGN_FOLDER     = 'LM_PMPNN_GRID_Functions_011'
FOLDER_MATCH      = 'MATCH' #Not needed for now -> This is just for match
FOLDER_PARENT     = f'../../design/Parent_1ohp' # -> Adjust, contains ONLY parent pdbs
##########################################################################################################################
#### Input parameters ####################################################################################################
MAX_JOBS          = 30
N_PARENT_JOBS     = 10
MAX_DESIGNS       = 40000
KBT_BOLTZMANN     = 0.04
CST_WEIGHT        = 1.0
HIGHSCORE         = 0.93
NEG_BEST          = 0.79
ProteinMPNN_PROB  = 0.3
WT                = "1ohp"
LIGAND            = "5TS"
REPACK            = "36,45,51,67"
MATCH             = "14,18,26,30,55,65,80,82,99,101,112"
DESIGN            = "7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78"
DESIGN           += ",80,82,84,86,93,95,97,99,101,103,109,112,114,116,121"
ProteinMPNN_T     = "0.1"
SUBMIT_PREFIX     = "PMPNN" # Adjust, use a short prefix to allow 
BLUEPEBBLE        = False
GRID              = True
BACKGROUND_JOB    = False

if GRID:            ROSETTA_PATH = "/home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/"      #GRID
if BLUEPEBBLE:      
                    ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
                    BLUEPEBBLE_ACCOUNT = "ptch000361"
                    #BLUEPEBBLE_ACCOUNT = "ptch000721"
if BACKGROUND_JOB:  ROSETTA_PATH = "/sw/apps/rosetta/rosetta_src_2021.16.61629_bundle/main/source/"   #BLUEPEBBLE 
    
NORM              = {'interface_score': [10, 35], 'total_score': [340, 500], 'catalytic_score': [-40, 0]}
##########################################################################################################################
AIZYME_TOOLS      = "../src/AIzymes_010.ipynb"
# %run "$AIZYME_TOOLS"
plot_scores()
# Out:
# AIzyme Functions loaded!
# catalytic_score [-40, 0] total_score [340, 500] interface_score [10, 35] HIGHSCORE: 0.86 Designs: 17095 Parents: 1

# %%
# %run "$AIZYME_TOOLS"
plot_pca_umap()
# Out:
# AIzyme Functions loaded!

# %%
# %run "$AIZYME_TOOLS"
plot_mut_location()
# Out:
# AIzyme Functions loaded!

# %%
# %run "$AIZYME_TOOLS"
plot_mut_location()
# Out:
# AIzyme Functions loaded!

# %%
# %run "$AIZYME_TOOLS"
all_scores_df = pd.read_csv(ALL_SCORES_CSV)
run_LigandMPNN(1008, 9999999, all_scores_df)
# Out:
# AIzyme Functions loaded!
# 2024-04-09 13:54:09 - INFO - Extracted sequence with highest confidence: 0.4709 to /home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/9999999/LigandMPNN/1ohp_9999999.seq
# 2024-04-09 13:54:09 - INFO - Ran LigandMPNN for index 1008 and generated modifications for new index 9999999.
# 2024-04-09 13:54:10 - INFO - Run ProteinMPNN for index 9999999 based on index 1008.
# /home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_011/9999999/LigandMPNN/1ohp_9999999.seq

# %%
# %run "$AIZYME_TOOLS"
controller(RESET=True, EXPLORE=False, UNBLOCK_ALL=False, PRINT_VAR=True, PLOT_DATA=False)
# Out:
# AIzyme Functions loaded!
# 2024-04-02 23:20:52 - INFO - Running AI.zymes setup.
# 2024-04-02 23:20:52 - INFO - Content of /home/lmerlicek/AIzymes/design/LM_PMPNN_GRID_Functions_012_004 deleted.
# 2024-04-02 23:20:52 - INFO - Happy AI.zymeing! :)
# 2024-04-02 23:20:52 - WARNING - To ensure a smooth start, N_PARENT_JOBS should be at least 2 x MAX_JOBS.
# 2024-04-02 23:20:52 - WARNING - N_PARENT_JOBS: 10, MAX_JOBS: 30.
# DESIGN_FOLDER    : LM_PMPNN_GRID_Functions_012_004
# FOLDER_MATCH     : MATCH
# MAX_JOBS         : 30
# N_PARENT_JOBS    : 10
# MAX_DESIGNS      : 40000
# KBT_BOLTZMANN    : 0.04
# CST_WEIGHT       : 1.0
# ProteinMPNN_PROB : 0.3
# WT               : 1ohp
# LIGAND           : 5TS
# ROSETTA_PATH     : /home/bunzelh/rosetta_src_2021.16.61629_bundle/main/source/
# REPACK           : 36,45,51,67
# DESIGN           : 7,10,11,14,15,18,26,29,30,38,54,55,58,59,63,65,71,73,78,80,82,84,86,93,95,97,99,101,103,109,112,114,116,121
# MATCH            : 14,18,26,30,55,65,80,82,99,101,112
# FOLDER_PARENT    : ../../design/Parent_1ohp
# ProteinMPNN_T    : 0.1
# SUBMIT_PREFIX    : PMPNN004
# BLUEPEBBLE       : False
# GRID             : True
# BACKGROUND_JOB   : False
# EXPLORE          : False
# 2024-04-02 23:20:53 - INFO - Run RosettaDesign for index 0 based on index 1ohp.
# 2024-04-02 23:20:55 - INFO - Run RosettaDesign for index 1 based on index 1ohp.
# 2024-04-02 23:20:56 - INFO - Run RosettaDesign for index 2 based on index 1ohp.
# 2024-04-02 23:20:57 - INFO - Run RosettaDesign for index 3 based on index 1ohp.
# 2024-04-02 23:20:59 - INFO - Run RosettaDesign for index 4 based on index 1ohp.
# 2024-04-02 23:21:00 - INFO - Run RosettaDesign for index 5 based on index 1ohp.
# 2024-04-02 23:21:01 - INFO - Run RosettaDesign for index 6 based on index 1ohp.
# 2024-04-02 23:21:03 - INFO - Run RosettaDesign for index 7 based on index 1ohp.
# 2024-04-02 23:21:04 - INFO - Run RosettaDesign for index 8 based on index 1ohp.
# 2024-04-02 23:21:05 - INFO - Run RosettaDesign for index 9 based on index 1ohp.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /home/lmerlicek/AIzymes/design/LM_Test_PMPNN_Grid.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Blmerlicek@bs-submit04.ethz.ch/home/lmerlicek/AIzymes/design/LM_Test_PMPNN_Grid.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
# ----> <a href='vscode-notebook-cell://ssh-remote%2Blmerlicek@bs-submit04.ethz.ch/home/lmerlicek/AIzymes/design/LM_Test_PMPNN_Grid.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> controller(RESET=True, EXPLORE=False, UNBLOCK_ALL=False, PRINT_VAR=True, PLOT_DATA=False)
#
# File /tmp/ipykernel_17739/731967013.py:19, in controller(RESET, EXPLORE, UNBLOCK_ALL, PRINT_VAR, PLOT_DATA, BLUEPEBBLE, GRID)
#      11 all_scores_df = startup_controller(UNBLOCK_ALL,
#      12                                    RESET,
#      13                                    PRINT_VAR=PRINT_VAR,
#      14                                    PLOT_DATA=PLOT_DATA)
#      16 while not os.path.exists(os.path.join(FOLDER_HOME, str(MAX_DESIGNS))):
#      17
#      18     # Check how many jobs are currently running
# ---> 19     num_running_jobs = check_running_jobs()
#      21     if num_running_jobs >= MAX_JOBS:
#      23         time.sleep(60)
#
# File /tmp/ipykernel_17739/731967013.py:49, in check_running_jobs()
#      46 def check_running_jobs():
#      48     if GRID:
# ---> 49         jobs = subprocess.check_output(["qstat", "-u", USERNAME]).decode("utf-8").split("\n")
#      50         jobs = [job for job in jobs if SUBMIT_PREFIX in job]
#      51         return len(jobs)
#
# File ~/miniconda3/envs/py37/lib/python3.9/subprocess.py:424, in check_output(timeout, *popenargs, **kwargs)
#     421         empty = b''
#     422     kwargs['input'] = empty
# --> 424 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425            **kwargs).stdout
#
# File ~/miniconda3/envs/py37/lib/python3.9/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     502     kwargs['stdout'] = PIPE
#     503     kwargs['stderr'] = PIPE
# --> 505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
#     507         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/miniconda3/envs/py37/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/py37/lib/python3.9/subprocess.py:1754, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1752     fds_to_keep = set(pass_fds)
#    1753     fds_to_keep.add(errpipe_write)
# -> 1754     self.pid = _posixsubprocess.fork_exec(
#    1755             args, executable_list,
#    1756             close_fds, tuple(sorted(map(int, fds_to_keep))),
#    1757             cwd, env_list,
#    1758             p2cread, p2cwrite, c2pread, c2pwrite,
#    1759             errread, errwrite,
#    1760             errpipe_read, errpipe_write,
#    1761             restore_signals, start_new_session,
#    1762             gid, gids, uid, umask,
#    1763             preexec_fn)
#    1764     self._child_created = True
#    1765 finally:
#    1766     # be sure the FD is closed no matter what
#
# OSError: [Errno 12] Cannot allocate memory

# %%
# !qstat | grep MATCH
#!qstat | grep MATCH | awk '{print $1}' | xargs -I {} qdel {}
# Out:
#  922690 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:34:01 regular.q@bs-grid66.ethz.ch        1
#  922728 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:42:01 regular.q@bs-grid78.ethz.ch        1
#  922744 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:45:01 regular.q@bs-grid77.ethz.ch        1
#  922758 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:46:46 regular.q@bs-dsvr57.ethz.ch        1
#  922770 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:47:31 regular.q@bs-dsvr57.ethz.ch        1
#  922777 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:48:01 regular.q@bs-dsvr57.ethz.ch        1
#  922783 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:49:16 regular.q@bs-grid68.ethz.ch        1
#  922784 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:49:46 regular.q@bs-grid68.ethz.ch        1
#  922785 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:50:01 regular.q@bs-grid68.ethz.ch        1
#  922793 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:51:01 regular.q@bs-dsvr69.ethz.ch        1
#  922795 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:52:01 regular.q@bs-grid70.ethz.ch        1
#  922799 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:53:31 regular.q@bs-grid72.ethz.ch        1
#  922800 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:54:01 regular.q@bs-grid67.ethz.ch        1
#  922803 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:55:31 regular.q@bs-grid67.ethz.ch        1
#  922804 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:56:01 regular.q@bs-grid77.ethz.ch        1
#  922812 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:56:31 regular.q@bs-grid77.ethz.ch        1
#  922816 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:57:31 regular.q@bs-grid75.ethz.ch        1
#  922817 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:58:01 regular.q@bs-grid78.ethz.ch        1
#  922819 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 10:59:16 regular.q@bs-dsvr69.ethz.ch        1
#  922826 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:00:46 regular.q@bs-dsvr56.ethz.ch        1
#  922842 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:02:16 regular.q@bs-grid66.ethz.ch        1
#  922850 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:03:16 regular.q@bs-dsvr69.ethz.ch        1
#  922851 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:04:01 regular.q@bs-dsvr69.ethz.ch        1
#  922853 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:04:46 regular.q@bs-dsvr56.ethz.ch        1
#  922867 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:07:46 regular.q@bs-dsvr56.ethz.ch        1
#  922873 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:25:46 regular.q@bs-grid64.ethz.ch        1
#  922874 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:25:46 regular.q@bs-grid64.ethz.ch        1
#  922886 0.55500 MATCH_ESMf lmerlicek    r     04/04/2024 11:30:16 regular.q@bs-grid69.ethz.ch        1
#  922897 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:09:05                                    1
#  922906 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:09:37                                    1
#  922915 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:10:11                                    1
#  922924 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:10:46                                    1
#  922930 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:11:34                                    1
#  922931 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:12:06                                    1
#  922932 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:12:36                                    1
#  922934 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:13:08                                    1
#  922935 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:13:45                                    1
#  922936 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:14:06                                    1
#  922937 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:14:28                                    1
#  922939 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:15:09                                    1
#  922940 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:15:31                                    1
#  922941 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:15:52                                    1
#  922947 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:16:27                                    1
#  922949 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:16:56                                    1
#  922950 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:17:24                                    1
#  922951 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:17:57                                    1
#  922958 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:18:26                                    1
#  922959 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:18:59                                    1
#  922960 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:19:28                                    1
#  922961 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:19:48                                    1
#  922963 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:20:10                                    1
#  922964 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:20:28                                    1
#  922965 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:20:44                                    1
#  922966 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:21:17                                    1
#  922967 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:21:41                                    1
#  922969 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:22:00                                    1
#  922970 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:22:24                                    1
#  922971 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:22:43                                    1
#  922972 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:23:01                                    1
#  922973 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:23:25                                    1
#  922975 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:23:46                                    1
#  922976 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:24:04                                    1
#  922977 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:24:35                                    1
#  922978 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:24:54                                    1
#  922979 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:25:08                                    1
#  922984 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:25:29                                    1
#  922986 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:25:52                                    1
#  922987 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:26:14                                    1
#  922988 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:26:36                                    1
#  922989 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:26:58                                    1
#  922992 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:27:17                                    1
#  922993 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:27:37                                    1
#  922994 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:28:15                                    1
#  922997 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:28:51                                    1
#  923002 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:29:32                                    1
#  923003 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:30:06                                    1
#  923004 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:30:42                                    1
#  923008 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:31:09                                    1
#  923009 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:31:35                                    1
#  923010 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:32:07                                    1
#  923011 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:32:54                                    1
#  923019 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:33:30                                    1
#  923020 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:34:04                                    1
#  923021 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:34:28                                    1
#  923022 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:34:56                                    1
#  923031 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:35:23                                    1
#  923034 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:36:00                                    1
#  923035 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:36:37                                    1
#  923036 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:37:04                                    1
#  923041 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:37:31                                    1
#  923042 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:38:03                                    1
#  923043 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:38:26                                    1
#  923047 0.55500 MATCH_ESMf lmerlicek    qw    04/04/2024 11:38:57                                    1

# %%
# %run "$AIZYME_TOOLS"
all_scores_df = pd.read_csv(f"{DESIGN_FOLDER}/all_scores.csv")
display(all_scores_df)

# %%
# %run "$AIZYME_TOOLS"
get_best_structures()
# Out:
# AIzyme Functions loaded!
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /tmp/ipykernel_8535/2690132606.py in <module>
#       1 get_ipython().run_line_magic('run', '"$AIZYME_TOOLS"')
# ----> 2 get_best_structures()
#
# /tmp/ipykernel_8535/2580291326.py in get_best_structures()
#     192
#     193     # Read the scores DataFrame
# --> 194     all_scores_df = pd.read_csv('/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv')
#     195
#     196     # Drop rows with NaN in 'total_score'
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: '/home/bunzelh/231126_Aizymes_RL/Design_MATCH_AI/all_scores.csv'

# %%
# !qstat

# %%
make_empty_all_scores_df()
# Out:
# Empty DataFrame
# Columns: [index, sequence, parent_index, interface_score, total_score, catalytic_score, interface_potential, total_potential, catalytic_potential, relax_interface_score, relax_total_score, relax_catalytic_score, design_interface_score, design_total_score, design_catalytic_score, generation, mutations, design_method, score_taken_from, blocked, cat_resi, cat_resn]
# Index: []
#
# [0 rows x 22 columns]

# %%
# !qdel 859581 859582 859583 859584 859586 859587 859588 859589 859590 859594 859595 859600 859604 859610 859611 859613 859614 859615 859619 859620 859629 859632 859633 859634 859635 859636 859637 859638 859639 859640 859641 859642 859643 859644 859645 859646 859647 859648 859649 859650 859651 859652 859653 859654 859655 859656 859657 859658 859659 859660 859661 859662 859663 859664 859665 859666 859667 859668 859669 859670 859671 859672 859673 859674 859675 859676
# Out:
# lmerlicek has registered the job 859581 for deletion
# lmerlicek has registered the job 859582 for deletion
# lmerlicek has registered the job 859583 for deletion
# lmerlicek has registered the job 859584 for deletion
# lmerlicek has registered the job 859586 for deletion
# lmerlicek has registered the job 859587 for deletion
# lmerlicek has registered the job 859588 for deletion
# job 859589 is already in deletion
# lmerlicek has registered the job 859590 for deletion
# job 859594 is already in deletion
# job 859595 is already in deletion
# lmerlicek has registered the job 859600 for deletion
# denied: job "859604" does not exist
# denied: job "859610" does not exist
# lmerlicek has registered the job 859611 for deletion
# lmerlicek has registered the job 859613 for deletion
# denied: job "859614" does not exist
# lmerlicek has registered the job 859615 for deletion
# lmerlicek has registered the job 859619 for deletion
# lmerlicek has registered the job 859620 for deletion
# denied: job "859629" does not exist
# lmerlicek has registered the job 859632 for deletion
# lmerlicek has registered the job 859633 for deletion
# lmerlicek has registered the job 859634 for deletion
# lmerlicek has registered the job 859635 for deletion
# lmerlicek has registered the job 859636 for deletion
# lmerlicek has registered the job 859637 for deletion
# lmerlicek has registered the job 859638 for deletion
# lmerlicek has registered the job 859639 for deletion
# lmerlicek has registered the job 859640 for deletion
# lmerlicek has registered the job 859641 for deletion
# lmerlicek has registered the job 859642 for deletion
# lmerlicek has registered the job 859643 for deletion
# lmerlicek has registered the job 859644 for deletion
# lmerlicek has registered the job 859645 for deletion
# lmerlicek has registered the job 859646 for deletion
# lmerlicek has registered the job 859647 for deletion
# lmerlicek has registered the job 859648 for deletion
# lmerlicek has registered the job 859649 for deletion
# lmerlicek has registered the job 859650 for deletion
# lmerlicek has registered the job 859651 for deletion
# lmerlicek has registered the job 859652 for deletion
# lmerlicek has registered the job 859653 for deletion
# lmerlicek has registered the job 859654 for deletion
# lmerlicek has registered the job 859655 for deletion
# lmerlicek has registered the job 859656 for deletion
# lmerlicek has registered the job 859657 for deletion
# lmerlicek has registered the job 859658 for deletion
# lmerlicek has registered the job 859659 for deletion
# lmerlicek has registered the job 859660 for deletion
# lmerlicek has registered the job 859661 for deletion
# lmerlicek has registered the job 859662 for deletion
# lmerlicek has registered the job 859663 for deletion
# lmerlicek has registered the job 859664 for deletion
# lmerlicek has registered the job 859665 for deletion
# lmerlicek has registered the job 859666 for deletion
# lmerlicek has registered the job 859667 for deletion
# lmerlicek has registered the job 859668 for deletion
# lmerlicek has registered the job 859669 for deletion
# lmerlicek has registered the job 859670 for deletion
# lmerlicek has registered the job 859671 for deletion
# lmerlicek has registered the job 859672 for deletion
# lmerlicek has registered the job 859673 for deletion
# lmerlicek has registered the job 859674 for deletion
# lmerlicek has registered the job 859675 for deletion
# lmerlicek has registered the job 859676 for deletion
